# %%
import os
import numpy as np
import itertools
train_path = 'D:/dataset/data_2013/origin_npy/Fpz-Cz/remove_wake/'
annotations_path = 'D:/dataset/data_2013/origin_npy/annotations/remove_wake/'

# %%
def search_correct_annotations_npy(dirname,filename):
    search_filename = filename.split('-')[0][:-2]
    file_list = os.listdir(dirname)
    filename = [file for file in file_list if search_filename in file if file.endswith("npy")]
    
    return filename

# %%
train_list = os.listdir(train_path)
train_list = [file for file in train_list if file.endswith('.npy')]
print(len(train_list))
# Out:
# 38

# %%
train_save_path = train_path + 'each/'
os.makedirs(train_save_path,exist_ok=True)
for i in range(6):
    os.makedirs(train_save_path+'%d/'%i,exist_ok=True)

# %%
print(train_save_path)
# Out:
# D:/dataset/data_2013/origin_npy/Fpz-Cz/remove_wake/each/

# %%
# total_index = 0
# for filename in train_list:
#     signals = np.load(train_path+filename)
#     annotations_name = search_correct_annotations_npy(annotations_path,filename)[0]
#     labels = np.load(annotations_path+annotations_name)
    
#     sample_rate = 100
#     sec = 30
    
#     for index in range(len(labels)):
#         save_signals = signals[0,index*sample_rate*sec:(index+1)*sample_rate*sec]
#         save_file = train_save_path+'%d/%d'%(labels[index],total_index)
#         np.save(save_file,save_signals)
#         total_index += 1

# %%
train_signals_path = 'D:/dataset/data_2013/origin_npy/Fpz-Cz/remove_wake/each/'

print(len(os.listdir(train_signals_path+'0/')))
print(len(os.listdir(train_signals_path+'1/')))
print(len(os.listdir(train_signals_path+'2/')))
print(len(os.listdir(train_signals_path+'3/')))
print(len(os.listdir(train_signals_path+'4/')))
print(len(os.listdir(train_signals_path+'5/')))
# Out:
# 4258
# 2762
# 17340
# 5575
# 7522
# 59

# %%
check_label = np.zeros(6)
for filename in train_list:
    annotations_name = search_correct_annotations_npy(annotations_path,filename)[0]
    labels = np.load(annotations_path+annotations_name)
    for i in labels:
        check_label[i] += 1

# %%
print(check_label)
# Out:
# [ 4258.  2762. 17340.  5575.  7522.    59.]

# %%
import numpy as np
import os
import time
import matplotlib.pylab as plt
from  torch.utils.data import Dataset
from torchvision import datasets, transforms
import sys
import random
import math
import warnings
import pandas as pd

from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import torch
from torchsummary import summary
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def data_preprocessing_torch(signals): # 하나의 데이터셋에 대한 data_preprocessing (using torch)
    signals = (signals - signals.mean(dim=1).unsqueeze(1))/signals.std(dim=1).unsqueeze(1)

    return signals



def data_preprocessing_oneToOne_torch(signals,min,max,max_value):
    signals_std = (signals + max_value) / (2*max_value)
    signals_scaled = signals_std * (max - min) + min
    return signals_scaled

def data_preprocessing_minmax_torch(signals,min,max):
    signals_std = (signals - signals.min(dim=1).unsqueeze(1)) / (
            signals.max(dim=1).unsqueeze(1) - signals.min(dim=1).unsqueeze(1))
    signals_scaled = signals_std * (max - min) + min
    return signals_scaled

def get_dataset_one_channel_norm_withoutCut(dirname,annotations_dir,data_path,use_noise=True,epsilon=0.5,noise_scale=2e-6,preprocessing=True,norm_methods='Standard'):
    # npy read!
    path = dirname + data_path
    signals = np.load(path)

    signals = torch.from_numpy(signals).float().to(device)

    if use_noise:
        if np.random.rand() < epsilon:
            # noise = np.random.normal(loc=0,scale=noise_scale,size=signals.shape)
            # signals = signals + noise
            noise = torch.normal(mean=0., std=noise_scale, size=signals.shape).to(device)
            signals = signals + noise

    if preprocessing:
        if norm_methods == 'Standard':
            signals = data_preprocessing_torch(signals)
        elif norm_methods == 'minmax':
            signals = data_preprocessing_minmax_torch(signals,0,1)
        elif norm_methods == 'oneToOne':
            signals = data_preprocessing_oneToOne_torch(signals,-1,1,1e-4)
    label = get_annotations(annotations_dir, data_path)
    return signals, label

# model conv layer weight init function
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:         # Conv weight init
        torch.nn.init.xavier_uniform_(m.weight.data)
        
def suffle_dataset_list(dataset_list): # 데이터 셔플
    random.shuffle(dataset_list)
    return dataset_list


# npy파일을 통해 label을 가져오는 함수
def get_annotations(label_dir,file_name):
    label_path = label_dir + file_name
    label = np.load(label_path)
    return label

def signals_expand_torch_one_channel(signals): # 2차원 데이터를 3차원으로 변환 (8,N) -> (batch,8,6000) 형태로
    signals = signals.expand(1,1,-1)
    #print(signals.shape)
    signals = signals.transpose(2, 1) # 차원 변경
    signals = signals.reshape(-1, 3000, 1) # 형태 변환
    signals = signals.transpose(2, 1) # 차원 변경
    return signals

# %%
class DeepSleepNet_Classification(nn.Module):  # input channel = 8channel / output = 5
    def __init__(self,in_channel=1,out_channel=6,layer=[64,128,128,128],sample_rate = 100):
        super(DeepSleepNet_Classification, self).__init__()

        self.conv1_1d_big = nn.Conv1d(in_channels=in_channel, out_channels=layer[0], kernel_size=sample_rate*4, stride=sample_rate//2,
                                      padding=sample_rate*4//2,
                                      bias=False)
        self.conv2_1d_big = nn.Conv1d(in_channels=layer[0], out_channels=layer[1], kernel_size=6, stride=1, padding=3,
                                      bias=False)
        self.conv3_1d_big_1 = nn.Conv1d(in_channels=layer[1], out_channels=layer[2], kernel_size=6, stride=1, padding=3,
                                        bias=False)
        self.conv3_1d_big_2 = nn.Conv1d(in_channels=layer[2], out_channels=layer[3], kernel_size=6, stride=1, padding=3,
                                        bias=False)
        self.maxpool1_big = nn.MaxPool1d(kernel_size=4, stride=4, padding=2)
        self.maxpool2_big = nn.MaxPool1d(kernel_size=2, stride=2, padding=1)

        self.conv1_1d_small = nn.Conv1d(in_channels=in_channel, out_channels=layer[0], kernel_size=sample_rate//2, stride=sample_rate//16,
                                        padding=sample_rate//2//2,
                                        bias=False)
        self.conv2_1d_small = nn.Conv1d(in_channels=layer[0], out_channels=layer[1], kernel_size=8, stride=1, padding=4,
                                        bias=False)
        self.conv3_1d_small_1 = nn.Conv1d(in_channels=layer[1], out_channels=layer[2], kernel_size=8, stride=1,
                                          padding=4,
                                          bias=False)
        self.conv3_1d_small_2 = nn.Conv1d(in_channels=layer[2], out_channels=layer[3], kernel_size=8, stride=1,
                                          padding=4,
                                          bias=False)
        self.maxpool1_small = nn.MaxPool1d(kernel_size=8, stride=8, padding=4)
        self.maxpool2_small = nn.MaxPool1d(kernel_size=4, stride=4, padding=2)

        self.ReLU = nn.ReLU()

        self.batch_norm_small_1 = nn.BatchNorm1d(64)
        self.batch_norm_small_2 = nn.BatchNorm1d(128)
        self.batch_norm_small_3 = nn.BatchNorm1d(128)
        self.batch_norm_small_4 = nn.BatchNorm1d(128)

        self.batch_norm_big_1 = nn.BatchNorm1d(64)
        self.batch_norm_big_2 = nn.BatchNorm1d(128)
        self.batch_norm_big_3 = nn.BatchNorm1d(128)
        self.batch_norm_big_4 = nn.BatchNorm1d(128)

        self.dropout_big = nn.Dropout(p=0.5)
        self.dropout_small = nn.Dropout(p=0.5)

        self.fc = nn.Linear(1280 + 2176, out_channel)  # big and small conv concat
        #self.fc2 = nn.Linear(1000, 5)  # big and small conv concat\
        # Dense 부분에서도 Bias없이 해볼 것!
        # self.fc = nn.Linear(384+8250,5,bias=False)

    def forward(self, input):
        # print("feature_extract_2d.shape : ", feature_extract_2d.shape)
        # 여기서 문제 발생 weight의 경우에는 [64 , 32 , 100] 이지만 input 이 2차원 [32, 750]이라 문제 발생!
        feature_big = self.conv1_1d_big(input)
        feature_big = self.batch_norm_big_1(feature_big)
        feature_big = self.ReLU(feature_big)

        feature_big = self.maxpool1_big(feature_big)

        feature_big = self.dropout_big(feature_big)

        feature_big = self.conv2_1d_big(feature_big)
        feature_big = self.batch_norm_big_2(feature_big)
        feature_big = self.ReLU(feature_big)

        feature_big = self.conv3_1d_big_1(feature_big)
        feature_big = self.batch_norm_big_3(feature_big)
        feature_big = self.ReLU(feature_big)

        feature_big = self.conv3_1d_big_2(feature_big)
        feature_big = self.batch_norm_big_4(feature_big)
        feature_big = self.ReLU(feature_big)

        feature_big = self.maxpool2_big(feature_big)

        feature_small = self.conv1_1d_small(input)
        feature_small = self.batch_norm_small_1(feature_small)
        feature_small = self.ReLU(feature_small)

        feature_small = self.maxpool1_small(feature_small)
        feature_small = self.dropout_small(feature_small)

        feature_small = self.conv2_1d_small(feature_small)
        feature_small = self.batch_norm_small_2(feature_small)
        feature_small = self.ReLU(feature_small)

        feature_small = self.conv3_1d_small_1(feature_small)
        feature_small = self.batch_norm_small_3(feature_small)
        feature_small = self.ReLU(feature_small)

        feature_small = self.conv3_1d_small_2(feature_small)
        feature_small = self.batch_norm_small_4(feature_small)
        feature_small = self.ReLU(feature_small)

        feature_small = self.maxpool2_small(feature_small)

        feature_big = torch.flatten(feature_big, 1)

        feature_small = torch.flatten(feature_small, 1)  # (batch, channel)

        output = torch.cat((feature_big, feature_small), dim=1)
        output = self.fc(output)

        return output

# %%
model = DeepSleepNet_Classification()
summary(model.cuda(),(1,3000))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv1d-1               [-1, 64, 61]          25,600
#        BatchNorm1d-2               [-1, 64, 61]             128
#               ReLU-3               [-1, 64, 61]               0
#          MaxPool1d-4               [-1, 64, 16]               0
#            Dropout-5               [-1, 64, 16]               0
#             Conv1d-6              [-1, 128, 17]          49,152
#        BatchNorm1d-7              [-1, 128, 17]             256
#               ReLU-8              [-1, 128, 17]               0
#             Conv1d-9              [-1, 128, 18]          98,304
#       BatchNorm1d-10              [-1, 128, 18]             256
#              ReLU-11              [-1, 128, 18]               0
#            Conv1d-12              [-1, 128, 19]          98,304
#       BatchNorm1d-13              [-1, 128, 19]             256
#              ReLU-14              [-1, 128, 19]               0
#         MaxPool1d-15              [-1, 128, 10]               0
#            Conv1d-16              [-1, 64, 501]           3,200
#       BatchNorm1d-17              [-1, 64, 501]             128
#              ReLU-18              [-1, 64, 501]               0
#         MaxPool1d-19               [-1, 64, 63]               0
#           Dropout-20               [-1, 64, 63]               0
#            Conv1d-21              [-1, 128, 64]          65,536
#       BatchNorm1d-22              [-1, 128, 64]             256
#              ReLU-23              [-1, 128, 64]               0
#            Conv1d-24              [-1, 128, 65]         131,072
#       BatchNorm1d-25              [-1, 128, 65]             256
#              ReLU-26              [-1, 128, 65]               0
#            Conv1d-27              [-1, 128, 66]         131,072
#       BatchNorm1d-28              [-1, 128, 66]             256
#              ReLU-29              [-1, 128, 66]               0
#         MaxPool1d-30              [-1, 128, 17]               0
#            Linear-31                    [-1, 6]          20,742
# ================================================================
# Total params: 624,774
# Trainable params: 624,774
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.66
# Params size (MB): 2.38
# Estimated Total Size (MB): 4.05
# ----------------------------------------------------------------

# %%
def search_npy_list(dirname):  # 매개변수 dir에서 모든 npy파일을 찾고 fold에 따른 dataset 나누기
    filenames = os.listdir(dirname)
    filenames = [file for _, file in enumerate(filenames) if file.endswith(".npy")]
    return filenames

# %%
def search_npy_list_withdir(dirname):  # 매개변수 dir에서 모든 npy파일을 찾고 fold에 따른 dataset 나누기
    filenames = os.listdir(dirname)
    filenames = [dirname+file for _, file in enumerate(filenames) if file.endswith(".npy")]
    return filenames

# %%
def CB_focal_loss(labels, logits, alpha, gamma):

    BCLoss = F.binary_cross_entropy_with_logits(input = logits, target = labels,reduction = "none")

    if gamma == 0.0:
        modulator = 1.0
    else:
        modulator = torch.exp(-gamma * labels * logits - gamma * torch.log(1 +
            torch.exp(-1.0 * logits)))

    loss = modulator * BCLoss

    weighted_loss = alpha * loss
    focal_loss = torch.sum(weighted_loss)

    focal_loss /= torch.sum(labels)
    return focal_loss


# saples_per_cls = 샘플의 비율
# no_of_classes = 클래스의 수
#
class CB_loss(nn.Module):
    def __init__(self,samples_per_cls, no_of_classes, loss_type, beta=0.9999, gamma=2.0):
        super(CB_loss,self).__init__()
        self.samples_per_cls = samples_per_cls
        self.no_of_classes = no_of_classes
        self.loss_type = loss_type
        self.beta = beta
        self.gamma = gamma

        self.effective_num = 1.0 - np.power(self.beta, self.samples_per_cls)
        #print(effective_num)
        self.weights = (1.0 - self.beta) / np.array(self.effective_num)
        #print(weights)
        self.weights = self.weights / np.sum(self.weights) * self.no_of_classes
        self.weights = torch.tensor(self.weights).float()
        self.weights = self.weights.to(device)

    def forward(self,logits,labels):

        #print(weights)
        #print(weights.shape)
        labels_one_hot = F.one_hot(labels, self.no_of_classes).float() # one-hot Encoding

        #print('weight to Float',weights)
        weights = self.weights.unsqueeze(0)# (5) -> (1,5) [1,1,1,1,1]->[[1,1,1,1,]]
        #print('weight unqueeze ',weights)
        #print('weight repeat without dot',weights.repeat(labels_one_hot.shape[0],1))
        weights = weights.repeat(labels_one_hot.shape[0],1) * labels_one_hot # label에 해당하는 위치의 weight값
        #
        #print('weights repeat ',weights)
        weights = weights.sum(1)

        #print('weight sum',weights)
        weights = weights.unsqueeze(1)
        #print('weight un squeeze',weights)
        weights = weights.repeat(1,self.no_of_classes) # 정답 class의 weight로 해당 batch의 모든 class weight 일치시킴
        #print('weight repeat',weights)

        if self.loss_type == "focal":
            cb_loss = CB_focal_loss(labels_one_hot, logits, weights, self.gamma)
        elif self.loss_type == "sigmoid":
            cb_loss = F.binary_cross_entropy_with_logits(input = logits,target = labels_one_hot, weight = weights)
        elif self.loss_type == "softmax":
            pred = logits.softmax(dim = 1)
            cb_loss = F.binary_cross_entropy(input = pred, target = labels_one_hot, weight = weights)
        return cb_loss

# %%
def get_dataset_one_channel_norm_withoutCut_each(file_name,use_noise,epsilon,
                                                 noise_scale,preprocessing,norm_methods):
    path = file_name
    signals = np.load(path)

    signals = torch.from_numpy(signals).float().to(device)
    signals = signals.reshape(1,-1)
    if use_noise:
        if np.random.rand() < epsilon:
            # noise = np.random.normal(loc=0,scale=noise_scale,size=signals.shape)
            # signals = signals + noise
            noise = torch.normal(mean=0., std=noise_scale, size=signals.shape).to(device)
            signals = signals + noise

    if preprocessing:
        if norm_methods == 'Standard':
            signals = data_preprocessing_torch(signals)
        elif norm_methods == 'minmax':
            signals = data_preprocessing_minmax_torch(signals,0,1)
        elif norm_methods == 'oneToOne':
            signals = data_preprocessing_oneToOne_torch(signals,-1,1,1e-4)
            
    label = int(file_name.split('/')[-2])
    label = np.array([label])
    return signals, label

# %%
def train_model_withNoise_norm(save_filename,logging_filename,train_signal_dir, test_signal_dir,annotations_dir
                               ,epochs=2000,learning_rate=0.001,step_size=100,gamma=0.5,channel=0,
                               layer_filters=[64,128,256,512],first_conv=[200,40,100],optim='Adam',lf='CE',
                               epsilon=0.7,noise_scale=2e-6,min_value=-1e-4,max_value=1e-4,preprocessing=True,
                               norm_methods='Standard',use_noise=True,loss_type='softmax'):
    # Adam optimizer param
    b1 = 0.5
    b2 = 0.999

    beta = 0.001

    check_file = open(logging_filename, 'w')  # logging file

    train_dataset_list = []
    
    for i in range(6):
        if i == 3:
            train_dataset_list.append(search_npy_list_withdir(train_signal_dir+'%d/'%i)[:2000])
        else:
            train_dataset_list.append(search_npy_list_withdir(train_signal_dir+'%d/'%i))
    
    train_dataset_list = list(itertools.chain(*train_dataset_list))
    print(len(train_dataset_list))

    best_accuracy = 0.
    best_epoch = 0

    test_dataset_list = search_npy_list(test_signal_dir)

    train_dataset_len = len(train_dataset_list)
    test_dataset_len = len(test_dataset_list)
    test_batch_size = test_dataset_len


    model = DeepSleepNet_Classification()

    #model = resnet18_200hz(in_channel=1,layer_filters=layer_filters,first_conv=first_conv,use_batchnorm=True,num_classes=5)

    model.apply(weights_init) # weight init

    cuda = torch.cuda.is_available()

    if cuda:
        print('can use CUDA!!!')
        model = model.cuda()
    #summary(model,[1,6000])
    print('torch.cuda.device_count() : ', torch.cuda.device_count())
    if torch.cuda.device_count() > 1:
        print('Multi GPU Activation !!!')
        #model = nn.DataParallel(model)

    # loss funcition
    if lf == 'CE':
        loss_fn = nn.CrossEntropyLoss().to(device)
    elif lf == 'CEW':
        samples_per_cls = [27,15,41,5,11]
        no_of_classes = 5
        effective_num = 1.0 - np.power(beta,samples_per_cls)
        #print(effective_num)
        weights = (1.0 - beta) / np.array(effective_num)
        #print(weights)
        weights = weights / np.sum(weights) * no_of_classes
        weights = torch.tensor(weights).float()
        weights = weights.to(device)
        loss_fn = nn.CrossEntropyLoss(weight=weights).to(device)
    elif lf == 'FL':
        loss_fn = FocalLoss(gamma=2).to(device)
    elif lf == 'CBL':
        loss_fn = CB_loss(samples_per_cls=[27,15,41,5,11],no_of_classes=5,loss_type=loss_type,beta=0.9999,gamma=2.0)
    #loss_fn = FocalLoss(gamma=2).to(device)

    # optimizer ADAM (SGD의 경우에는 정상적으로 학습이 진행되지 않았음)
    if optim == 'Adam':
        print('Optimizer : Adam')
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(b1, b2))
    elif optim == 'RMS':
        print('Optimizer : RMSprop')
        optimizer = torch.optim.RMSprop(model.parameters(), lr=learning_rate)
    elif optim == 'SGD':
        print('Optimizer : SGD')
        optimizer = torch.optim.SGD(model.parameters(),lr=learning_rate,momentum=0.9)

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer=optimizer, mode='min', factor=gamma, patience=10,
                                                           min_lr=1e-6)
    #stride = 40 일 때, batch_size = 20이면 16GB정도의 메모리 사용
    batch_size = 5000
    norm_square = 2

    
    for epoch in range(epochs):
        train_dataset = suffle_dataset_list(train_dataset_list) # 매 epoch마다 train_dataset shuffle !
        count = 0  # check batch
        train_total_loss = 0.0
        train_total_count = 0
        train_total_data = 0

        val_total_loss = 0.0
        val_total_count = 0
        val_total_data = 0

        test_total_loss = 0.0
        test_total_count = 0
        test_total_data = 0

        start_time = time.time()
        model.train()
        output_str = 'current_lr : %f\n'%(optimizer.state_dict()['param_groups'][0]['lr'])
        sys.stdout.write(output_str)
        check_file.write(output_str)
        train_size = 0
        for index, file_name in enumerate(train_dataset):
            if index % batch_size == 0:
                batch_signal, batch_label = get_dataset_one_channel_norm_withoutCut_each(file_name,
                                                                         use_noise=use_noise,epsilon=epsilon,noise_scale=noise_scale,
                                                                         preprocessing=preprocessing,norm_methods=norm_methods)
            else:
                new_signal, new_label = get_dataset_one_channel_norm_withoutCut_each(file_name,
                                                                         use_noise=use_noise,epsilon=epsilon,noise_scale=noise_scale,
                                                                         preprocessing=preprocessing,norm_methods=norm_methods)

                batch_signal = torch.cat((batch_signal, new_signal),dim=1)
                batch_label = np.concatenate((batch_label, new_label))
            count += 1
            if count == batch_size or index == len(train_dataset) - 1:  # batch 학습 시작!
                batch_signal = signals_expand_torch_one_channel(batch_signal)
                #batch_signal = signals_expand_torch_one_channel(batch_signal)
                # batch_signal = torch.from_numpy(batch_signal).float().to(device)
                batch_label = torch.from_numpy(batch_label).long().to(device)
                optimizer.zero_grad()
                # print(batch_signal.shape)
                # print(batch_signal)
                pred = model(batch_signal)
                norm = 0

                for parameter in model.parameters():
                    norm += torch.norm(parameter, p=norm_square)

                loss = loss_fn(pred, batch_label) + beta * norm
                #print('loss : ',loss.item())
                # loss = loss_fn(pred, batch_label)
                # acc
                _, predict = torch.max(pred, 1)
                check_count = (predict == batch_label).sum().item()

                train_total_loss += loss.item()
                train_size +=1
                train_total_count += check_count
                train_total_data += len(batch_signal)
                loss.backward()
                optimizer.step()

                del (batch_signal)
                del (batch_label)
                del (loss)
                del (pred)
                torch.cuda.empty_cache()
                count = 0
        print(train_total_loss)
        print(train_size)
        train_total_loss /= train_size
        train_accuracy = train_total_count / int(len(train_dataset_list)) * 100

        output_str = 'train dataset : %d/%d epochs spend time : %.4f sec / total_loss : %.4f correct : %d/%d -> %.4f%%\n' \
                     % (epoch + 1, epochs, time.time() - start_time, train_total_loss,
                        train_total_count, train_total_data, train_accuracy)
        sys.stdout.write(output_str)
        check_file.write(output_str)

    

        #check test dataset
        start_time = time.time()
        for file_name in test_dataset_list:
            batch_signal, batch_label = get_dataset_one_channel_norm_withoutCut(test_signal_dir,annotations_dir,file_name,
                                                                         use_noise=False,epsilon=epsilon,noise_scale=noise_scale,
                                                                         preprocessing=preprocessing,norm_methods=norm_methods)

            batch_signal = signals_expand_torch_one_channel(batch_signal)

            batch_label = torch.from_numpy(batch_label).long().to(device)

            with torch.no_grad():
                pred = model(batch_signal)

                loss = loss_fn(pred, batch_label)

                # acc
                _, predict = torch.max(pred, 1)
                check_count = (predict == batch_label).sum().item()

                test_total_loss += loss.item()
                test_total_count += check_count
                test_total_data += len(batch_signal)

                # 사용하지 않는 변수 제거
                del (batch_signal)
                del (batch_label)
                del (loss)
                del (pred)
                torch.cuda.empty_cache()
        test_total_loss /= test_batch_size
        test_accuracy = test_total_count / test_total_data * 100



        output_str = 'test dataset : %d/%d epochs spend time : %.4f sec  / total_loss : %.4f correct : %d/%d -> %.4f%%\n' \
                     % (epoch + 1, epochs, time.time() - start_time, test_total_loss,
                        test_total_count, test_total_data, test_accuracy)
        sys.stdout.write(output_str)
        check_file.write(output_str)

        scheduler.step(float(test_total_loss))
        #scheduler.step()

        if epoch == 0:
            best_accuracy = test_accuracy
            best_epoch = epoch
            save_file = save_filename
            #save_file = save_path + 'best_SleepEEGNet_CNN_channel%d.pth'%channel
            torch.save(model.state_dict(),save_file)
            stop_count = 0
        else:
            if best_accuracy < test_accuracy:
                best_accuracy = test_accuracy
                best_epoch = epoch
                save_file = save_filename
                torch.save(model.state_dict(), save_file)
                stop_count = 0
            else:
                stop_count += 1
        if stop_count > 30:
            print('Early Stopping')
            break

        output_str = 'best epoch : %d/%d / val accuracy : %f%%\n' \
                     % (best_epoch+1, epochs, best_accuracy)
        sys.stdout.write(output_str)
        print('=' * 30)


    output_str = 'best epoch : %d/%d / accuracy : %f%%\n' \
                 % (best_epoch+1, epochs, best_accuracy)
    sys.stdout.write(output_str)
    check_file.write(output_str)
    print('=' * 30)

    check_file.close()

# %%
save_filename = './train.pth'
logging_filename = './logging.txt'
train_signal_dir = 'D:/dataset/data_2013/origin_npy/Fpz-Cz/remove_wake/each/'
test_signal_dir = 'D:/dataset/data_2013/origin_npy/Fpz-Cz/remove_wake/test/'
annotations_dir = 'D:/dataset/data_2013/origin_npy/annotations/remove_wake/'
train_model_withNoise_norm(save_filename,logging_filename,train_signal_dir, 
                           test_signal_dir,annotations_dir,
                           epochs=2000,learning_rate=0.001,step_size=100,gamma=0.5,channel=0,
                           layer_filters=[64,128,256,512],first_conv=[200,40,100],
                           optim='Adam',lf='CE',epsilon=0,noise_scale=0,
                           min_value=-0,max_value=0,preprocessing=True,
                           norm_methods='Standard',use_noise=False,loss_type='softmax')
# Out:
# 33941
# can use CUDA!!!
# torch.cuda.device_count() :  1
# Optimizer : Adam
# current_lr : 0.001000
# 14.457378149032593
# 7
# train dataset : 1/2000 epochs spend time : 31.0596 sec / total_loss : 2.0653 correct : 13056/33941 -> 38.4668%
# test dataset : 1/2000 epochs spend time : 0.5290 sec  / total_loss : 2.4360 correct : 4260/9821 -> 43.3764%
# best epoch : 1/2000 / val accuracy : 43.376438%
# ==============================
# current_lr : 0.001000
# 8.283014416694641
# 7
# train dataset : 2/2000 epochs spend time : 30.9922 sec / total_loss : 1.1833 correct : 20241/33941 -> 59.6358%
# test dataset : 2/2000 epochs spend time : 0.5072 sec  / total_loss : 2.0848 correct : 4786/9821 -> 48.7323%
# best epoch : 2/2000 / val accuracy : 48.732308%
# ==============================
# current_lr : 0.001000
# 6.312838017940521
# 7
# train dataset : 3/2000 epochs spend time : 30.6198 sec / total_loss : 0.9018 correct : 24582/33941 -> 72.4257%
# test dataset : 3/2000 epochs spend time : 0.5132 sec  / total_loss : 1.7230 correct : 5705/9821 -> 58.0898%
# best epoch : 3/2000 / val accuracy : 58.089808%
# ==============================
# current_lr : 0.001000
# 5.857828319072723
# 7
# train dataset : 4/2000 epochs spend time : 30.5663 sec / total_loss : 0.8368 correct : 25385/33941 -> 74.7916%
# test dataset : 4/2000 epochs spend time : 0.5042 sec  / total_loss : 1.6687 correct : 6133/9821 -> 62.4478%
# best epoch : 4/2000 / val accuracy : 62.447816%
# ==============================
# current_lr : 0.001000
# 5.253601610660553
# 7
# train dataset : 5/2000 epochs spend time : 30.9935 sec / total_loss : 0.7505 correct : 26504/33941 -> 78.0884%
# test dataset : 5/2000 epochs spend time : 0.5072 sec  / total_loss : 1.4944 correct : 6389/9821 -> 65.0545%
# best epoch : 5/2000 / val accuracy : 65.054475%
# ==============================
# current_lr : 0.001000
# 5.055115342140198
# 7
# train dataset : 6/2000 epochs spend time : 31.2493 sec / total_loss : 0.7222 correct : 26834/33941 -> 79.0607%
# test dataset : 6/2000 epochs spend time : 0.5102 sec  / total_loss : 1.5162 correct : 6236/9821 -> 63.4966%
# best epoch : 5/2000 / val accuracy : 65.054475%
# ==============================
# current_lr : 0.001000
# 4.973887026309967
# 7
# train dataset : 7/2000 epochs spend time : 30.4840 sec / total_loss : 0.7106 correct : 26909/33941 -> 79.2817%
# test dataset : 7/2000 epochs spend time : 0.5023 sec  / total_loss : 1.5131 correct : 6645/9821 -> 67.6611%
# best epoch : 7/2000 / val accuracy : 67.661134%
# ==============================
# current_lr : 0.001000
# 4.876787006855011
# 7
# train dataset : 8/2000 epochs spend time : 30.2354 sec / total_loss : 0.6967 correct : 27158/33941 -> 80.0153%
# test dataset : 8/2000 epochs spend time : 0.5062 sec  / total_loss : 1.4310 correct : 6640/9821 -> 67.6102%
# best epoch : 7/2000 / val accuracy : 67.661134%
# ==============================
# current_lr : 0.001000
# 4.967307031154633
# 7
# train dataset : 9/2000 epochs spend time : 30.3939 sec / total_loss : 0.7096 correct : 26936/33941 -> 79.3612%
# test dataset : 9/2000 epochs spend time : 0.5072 sec  / total_loss : 1.5501 correct : 6567/9821 -> 66.8669%
# best epoch : 7/2000 / val accuracy : 67.661134%
# ==============================
# current_lr : 0.001000
# 4.761506736278534
# 7
# train dataset : 10/2000 epochs spend time : 30.8783 sec / total_loss : 0.6802 correct : 27332/33941 -> 80.5280%
# test dataset : 10/2000 epochs spend time : 0.5032 sec  / total_loss : 1.4342 correct : 6752/9821 -> 68.7506%
# best epoch : 10/2000 / val accuracy : 68.750636%
# ==============================
# current_lr : 0.001000
# 4.640457332134247
# 7
# train dataset : 11/2000 epochs spend time : 30.5494 sec / total_loss : 0.6629 correct : 27502/33941 -> 81.0288%
# test dataset : 11/2000 epochs spend time : 0.5052 sec  / total_loss : 1.4369 correct : 6616/9821 -> 67.3658%
# best epoch : 10/2000 / val accuracy : 68.750636%
# ==============================
# current_lr : 0.001000
# 5.067318975925446
# 7
# train dataset : 12/2000 epochs spend time : 30.4959 sec / total_loss : 0.7239 correct : 26837/33941 -> 79.0696%
# test dataset : 12/2000 epochs spend time : 0.5023 sec  / total_loss : 1.9045 correct : 6687/9821 -> 68.0888%
# best epoch : 10/2000 / val accuracy : 68.750636%
# ==============================
# current_lr : 0.001000
# 4.789439857006073
# 7
# train dataset : 13/2000 epochs spend time : 30.6178 sec / total_loss : 0.6842 correct : 27316/33941 -> 80.4808%
# test dataset : 13/2000 epochs spend time : 0.5013 sec  / total_loss : 1.5065 correct : 6813/9821 -> 69.3718%
# best epoch : 13/2000 / val accuracy : 69.371754%
# ==============================
# current_lr : 0.001000
# 4.633015155792236
# 7
# train dataset : 14/2000 epochs spend time : 30.5465 sec / total_loss : 0.6619 correct : 27537/33941 -> 81.1320%
# test dataset : 14/2000 epochs spend time : 0.5181 sec  / total_loss : 1.6010 correct : 6673/9821 -> 67.9462%
# best epoch : 13/2000 / val accuracy : 69.371754%
# ==============================
# current_lr : 0.001000
# 4.578474640846252
# 7
# train dataset : 15/2000 epochs spend time : 30.2631 sec / total_loss : 0.6541 correct : 27631/33941 -> 81.4089%
# test dataset : 15/2000 epochs spend time : 0.5122 sec  / total_loss : 1.3926 correct : 6752/9821 -> 68.7506%
# best epoch : 13/2000 / val accuracy : 69.371754%
# ==============================
# current_lr : 0.001000
# 4.564485132694244
# 7
# train dataset : 16/2000 epochs spend time : 30.2195 sec / total_loss : 0.6521 correct : 27653/33941 -> 81.4737%
# test dataset : 16/2000 epochs spend time : 0.5013 sec  / total_loss : 1.4400 correct : 6870/9821 -> 69.9521%
# best epoch : 16/2000 / val accuracy : 69.952143%
# ==============================
# current_lr : 0.001000
# 4.495852291584015
# 7
# train dataset : 17/2000 epochs spend time : 30.2512 sec / total_loss : 0.6423 correct : 27786/33941 -> 81.8656%
# test dataset : 17/2000 epochs spend time : 0.5032 sec  / total_loss : 1.1770 correct : 6840/9821 -> 69.6467%
# best epoch : 16/2000 / val accuracy : 69.952143%
# ==============================
# current_lr : 0.001000
# 4.486546993255615
# 7
# train dataset : 18/2000 epochs spend time : 30.2077 sec / total_loss : 0.6409 correct : 27826/33941 -> 81.9834%
# test dataset : 18/2000 epochs spend time : 0.5072 sec  / total_loss : 1.3852 correct : 6859/9821 -> 69.8401%
# best epoch : 16/2000 / val accuracy : 69.952143%
# ==============================
# current_lr : 0.001000
# 4.421286523342133
# 7
# train dataset : 19/2000 epochs spend time : 30.2938 sec / total_loss : 0.6316 correct : 27863/33941 -> 82.0925%
# test dataset : 19/2000 epochs spend time : 0.5141 sec  / total_loss : 1.4393 correct : 6864/9821 -> 69.8910%
# best epoch : 16/2000 / val accuracy : 69.952143%
# ==============================
# current_lr : 0.001000
# 4.3708415031433105
# 7
# train dataset : 20/2000 epochs spend time : 30.3067 sec / total_loss : 0.6244 correct : 28031/33941 -> 82.5874%
# test dataset : 20/2000 epochs spend time : 0.5042 sec  / total_loss : 1.3148 correct : 6820/9821 -> 69.4430%
# best epoch : 16/2000 / val accuracy : 69.952143%
# ==============================
# current_lr : 0.001000
# 4.403637051582336
# 7
# train dataset : 21/2000 epochs spend time : 30.2869 sec / total_loss : 0.6291 correct : 27938/33941 -> 82.3134%
# test dataset : 21/2000 epochs spend time : 0.5072 sec  / total_loss : 1.3497 correct : 6842/9821 -> 69.6670%
# best epoch : 16/2000 / val accuracy : 69.952143%
# ==============================
# current_lr : 0.001000
# 4.349157392978668
# 7
# train dataset : 22/2000 epochs spend time : 30.2384 sec / total_loss : 0.6213 correct : 28047/33941 -> 82.6346%
# test dataset : 22/2000 epochs spend time : 0.5052 sec  / total_loss : 1.4510 correct : 6756/9821 -> 68.7914%
# best epoch : 16/2000 / val accuracy : 69.952143%
# ==============================
# current_lr : 0.001000
# 4.329668760299683
# 7
# train dataset : 23/2000 epochs spend time : 30.5495 sec / total_loss : 0.6185 correct : 28081/33941 -> 82.7347%
# test dataset : 23/2000 epochs spend time : 0.5052 sec  / total_loss : 1.0019 correct : 6894/9821 -> 70.1965%
# best epoch : 23/2000 / val accuracy : 70.196518%
# ==============================
# current_lr : 0.001000
# 4.499113738536835
# 7
# train dataset : 24/2000 epochs spend time : 30.2760 sec / total_loss : 0.6427 correct : 27687/33941 -> 81.5739%
# test dataset : 24/2000 epochs spend time : 0.5092 sec  / total_loss : 1.2306 correct : 6697/9821 -> 68.1906%
# best epoch : 23/2000 / val accuracy : 70.196518%
# ==============================
# current_lr : 0.001000
# 4.296614348888397
# 7
# train dataset : 25/2000 epochs spend time : 30.2651 sec / total_loss : 0.6138 correct : 28117/33941 -> 82.8408%
# test dataset : 25/2000 epochs spend time : 0.5032 sec  / total_loss : 1.1685 correct : 6973/9821 -> 71.0009%
# best epoch : 25/2000 / val accuracy : 71.000916%
# ==============================
# current_lr : 0.001000
# 4

# best epoch : 25/2000 / val accuracy : 71.000916%
# ==============================
# current_lr : 0.000250
# 3.7237783074378967
# 7
# train dataset : 49/2000 epochs spend time : 30.0878 sec / total_loss : 0.5320 correct : 29159/33941 -> 85.9108%
# test dataset : 49/2000 epochs spend time : 0.5013 sec  / total_loss : 1.2249 correct : 6938/9821 -> 70.6445%
# best epoch : 25/2000 / val accuracy : 71.000916%
# ==============================
# current_lr : 0.000250
# 3.7183342576026917
# 7
# train dataset : 50/2000 epochs spend time : 29.9432 sec / total_loss : 0.5312 correct : 29184/33941 -> 85.9845%
# test dataset : 50/2000 epochs spend time : 0.5042 sec  / total_loss : 1.1399 correct : 6955/9821 -> 70.8176%
# best epoch : 25/2000 / val accuracy : 71.000916%
# ==============================
# current_lr : 0.000250
# 3.718963861465454
# 7
# train dataset : 51/2000 epochs spend time : 31.3450 sec / total_loss : 0.5313 correct : 29181/33941 -> 85.9757%
# test dataset : 51/2000 epochs spend time : 0.5112 sec  / total_loss : 1.2687 correct : 6857/9821 -> 69.8198%
# best epoch : 25/2000 / val accuracy : 71.000916%
# ==============================
# current_lr : 0.000250
# 3.707458019256592
# 7
# train dataset : 52/2000 epochs spend time : 31.1595 sec / total_loss : 0.5296 correct : 29192/33941 -> 86.0081%
# test dataset : 52/2000 epochs spend time : 0.5092 sec  / total_loss : 1.1760 correct : 6972/9821 -> 70.9907%
# best epoch : 25/2000 / val accuracy : 71.000916%
# ==============================
# current_lr : 0.000250
# 3.6936047673225403
# 7
# train dataset : 53/2000 epochs spend time : 30.7160 sec / total_loss : 0.5277 correct : 29228/33941 -> 86.1141%
# test dataset : 53/2000 epochs spend time : 0.5349 sec  / total_loss : 1.1824 correct : 6970/9821 -> 70.9704%
# best epoch : 25/2000 / val accuracy : 71.000916%
# ==============================
# current_lr : 0.000250
# 3.6830508708953857
# 7
# train dataset : 54/2000 epochs spend time : 30.7917 sec / total_loss : 0.5262 correct : 29218/33941 -> 86.0847%
# test dataset : 54/2000 epochs spend time : 0.5171 sec  / total_loss : 1.2486 correct : 6947/9821 -> 70.7362%
# best epoch : 25/2000 / val accuracy : 71.000916%
# ==============================
# current_lr : 0.000250
# 3.6577666997909546
# 7
# train dataset : 55/2000 epochs spend time : 30.7507 sec / total_loss : 0.5225 correct : 29309/33941 -> 86.3528%
# test dataset : 55/2000 epochs spend time : 0.5122 sec  / total_loss : 1.1737 correct : 7021/9821 -> 71.4897%
# best epoch : 55/2000 / val accuracy : 71.489665%
# ==============================
# current_lr : 0.000250
# 3.689678192138672
# 7
# train dataset : 56/2000 epochs spend time : 30.6461 sec / total_loss : 0.5271 correct : 29185/33941 -> 85.9874%
# test dataset : 56/2000 epochs spend time : 0.5132 sec  / total_loss : 1.2497 correct : 6913/9821 -> 70.3900%
# best epoch : 55/2000 / val accuracy : 71.489665%
# ==============================
# current_lr : 0.000125
# 3.610053062438965
# 7
# train dataset : 57/2000 epochs spend time : 30.6682 sec / total_loss : 0.5157 correct : 29368/33941 -> 86.5266%
# test dataset : 57/2000 epochs spend time : 0.5340 sec  / total_loss : 1.1979 correct : 6974/9821 -> 71.0111%
# best epoch : 55/2000 / val accuracy : 71.489665%
# ==============================
# current_lr : 0.000125
# 3.630915582180023
# 7
# train dataset : 58/2000 epochs spend time : 30.7073 sec / total_loss : 0.5187 correct : 29271/33941 -> 86.2408%
# test dataset : 58/2000 epochs spend time : 0.5141 sec  / total_loss : 1.1868 correct : 6941/9821 -> 70.6751%
# best epoch : 55/2000 / val accuracy : 71.489665%
# ==============================
# current_lr : 0.000125
# 3.6154457330703735
# 7
# train dataset : 59/2000 epochs spend time : 30.6857 sec / total_loss : 0.5165 correct : 29399/33941 -> 86.6180%
# test dataset : 59/2000 epochs spend time : 0.5122 sec  / total_loss : 1.2330 correct : 6921/9821 -> 70.4714%
# best epoch : 55/2000 / val accuracy : 71.489665%
# ==============================
# current_lr : 0.000125
# 3.6238166093826294
# 7
# train dataset : 60/2000 epochs spend time : 30.7547 sec / total_loss : 0.5177 correct : 29373/33941 -> 86.5414%
# test dataset : 60/2000 epochs spend time : 0.5141 sec  / total_loss : 1.2058 correct : 6966/9821 -> 70.9296%
# best epoch : 55/2000 / val accuracy : 71.489665%
# ==============================
# current_lr : 0.000125
# 3

# best epoch : 55/2000 / val accuracy : 71.489665%
# ==============================
# current_lr : 0.000031
# 3.5097931921482086
# 7
# train dataset : 85/2000 epochs spend time : 31.4928 sec / total_loss : 0.5014 correct : 29570/33941 -> 87.1218%
# test dataset : 85/2000 epochs spend time : 0.5301 sec  / total_loss : 1.2097 correct : 6955/9821 -> 70.8176%
# best epoch : 55/2000 / val accuracy : 71.489665%
# ==============================
# current_lr : 0.000031
# 3.4906928539276123
# 7
# train dataset : 86/2000 epochs spend time : 31.2637 sec / total_loss : 0.4987 correct : 29562/33941 -> 87.0982%
# test dataset : 86/2000 epochs spend time : 0.5265 sec  / total_loss : 1.2203 correct : 6952/9821 -> 70.7871%
# Early Stopping
# best epoch : 55/2000 / accuracy : 71.489665%
# ==============================

# %%
def check_ResNet_custom_Confusion(test_signals_dir,annotations_dir,load_filename,save_path):
    n_categories = 6
    columns_format = ['Wake','N1','N2','N3','REM','None']

    dataset = search_npy_list(test_signals_dir)
    print(dataset)


    model = DeepSleepNet_Classification()

    cuda = torch.cuda.is_available()

    if cuda:
        print('can use CUDA!!!')
        model = model.cuda()

    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")


    test_total_loss = 0.0
    test_total_count = 0
    test_total_data = 0

    model.load_state_dict(torch.load(load_filename))

    confusion = torch.zeros(n_categories, n_categories)

    # 평가 모델 사용
    model.eval()
    for file_name in dataset:
        # get_signal_each_onechannel()
        batch_signal, batch_label = get_dataset_one_channel_norm_withoutCut(test_signal_dir,annotations_dir,file_name,
                                                                         use_noise=False,epsilon=0,noise_scale=0,
                                                                         preprocessing=True,norm_methods='Standard')
        #print(batch_signal.shape)
        batch_label_cpu = batch_label
        batch_label = torch.from_numpy(batch_label).long().to(device)
        batch_signal = signals_expand_torch_one_channel(batch_signal)
        
        with torch.no_grad():
            for index,batch_signal_each in enumerate(batch_signal):
                pred = model(batch_signal_each.reshape(1,1,-1))

                # acc
                _, predict = torch.max(pred, 1)
                check_count = (predict == batch_label[index]).sum().item()
                batch_label_one = batch_label[index].cpu().numpy()
                predict = predict.cpu().numpy()
                
                
                confusion[batch_label[index]][predict] += 1

                test_total_count += check_count
                test_total_data += len(pred)
    print(confusion)
    confusion_percent = torch.zeros(n_categories, n_categories)
    confusion_percent_recall = torch.zeros(n_categories, n_categories)
    sensitivity = torch.zeros(n_categories)
    specificity = torch.zeros(n_categories)
    recall = torch.zeros(n_categories)
    precision = torch.zeros(n_categories)
    f1_score = torch.zeros(n_categories)

    tp_fp = confusion.sum(dim=0)
    tp_fn = confusion.sum(dim=1)
    tn_fp = torch.zeros(n_categories)
    for i in range(6):
        for z in range(6):
            if z != i:
                tn_fp[i] += tp_fn[z]
    for index in range(n_categories):
        confusion_percent[index] = confusion[index] / tp_fp.float()
        confusion_percent_recall[index] = confusion[index] / tp_fn.float()
        tn = confusion.sum() - confusion.sum(dim=0)[index] - confusion.sum(dim=1)[index] + confusion[index][index]
        sensitivity[index] = confusion[index][index] / float(tp_fn[index])
        specificity[index] = tn / float(tn_fp[index])
        precision[index] = confusion[index][index] / float(tp_fp[index])

        recall[index] = sensitivity[index]

    f1_score = 2 * (precision * recall) / (precision + recall)
    test_total_loss /= len(dataset)
    test_accuracy = test_total_count / test_total_data * 100
    print('Total data accuracy : %d/%d -> %.4f%%' % (test_total_count, test_total_data, test_accuracy))
    stdout = ''
    for i in range(6):
        stdout += '%.2f '%(confusion_percent[i][i]*100)
    stdout += '\n'
    sys.stdout.write(stdout)
    confusion_percent_f1 = 2 * (confusion_percent * confusion_percent_recall) / (
                confusion_percent + confusion_percent_recall)
    stdout = ''
    for i in range(6):
        stdout += '%.2f '%(confusion_percent_f1[i][i]*100)
    stdout += '\n'
    sys.stdout.write(stdout)

    label = ['Wake', 'N1', 'N2', 'N3', 'REM']
    # Plot confusion matrix
    plt.imshow(confusion_percent, interpolation='none', cmap='GnBu')
    for (i, j), z in np.ndenumerate(confusion_percent):
        # print(i, j, z)
        plt.text(j, i, '%.2f%%' % (z * 100), ha='center', va='center', color='Red', fontSize=11, fontweight='bold')
    plt.title('confusion_matrix_precision')
    plt.xticks(np.arange(0, 6), label)
    plt.yticks(np.arange(0, 6), label)
    plt.xlabel("pred label")
    plt.ylabel("truth label")
    plt.savefig(save_path+'confusion_matrix_%d.png')
    plt.show()

    plt.imshow(confusion_percent_f1, interpolation='none', cmap='GnBu')
    for (i, j), z in np.ndenumerate(confusion_percent_f1):
        # print(i, j, z)
        plt.text(j, i, '%.2f%%' % (z * 100), ha='center', va='center', color='Red', fontSize=11, fontweight='bold')
    plt.title('confusion_matrix_F1 score')
    plt.xticks(np.arange(0, 6), label)
    plt.yticks(np.arange(0, 6), label)
    plt.xlabel("pred label")
    plt.ylabel("truth label")
    plt.savefig(save_path+'confusion_matrix_f1score_%d.png')
    plt.show()

    print('sensitivity')
    print(sensitivity)
    print('specificity')
    print(specificity)
    print('recall')
    print(recall)
    print('precision')
    print(precision)
    print('f1_score')
    print(f1_score)

def make_result_channel_new():
    load_filename = './train.pth'
    logging_filename = './logging.txt'
    save_path = './result/'
    os.makedirs(save_path,exist_ok=True)
    test_signals_dir = 'D:/dataset/data_2013/origin_npy/Fpz-Cz/remove_wake/test/'
    annotations_dir = 'D:/dataset/data_2013/origin_npy/annotations/remove_wake/'
    check_ResNet_custom_Confusion(test_signals_dir,annotations_dir,load_filename,save_path)
make_result_channel_new()
# Out:
# ['SC4002EC-Hypnogram.npy', 'SC4022EJ-Hypnogram.npy', 'SC4031EC-Hypnogram.npy', 'SC4042EC-Hypnogram.npy', 'SC4072EH-Hypnogram.npy', 'SC4101EC-Hypnogram.npy', 'SC4141EU-Hypnogram.npy', 'SC4151EC-Hypnogram.npy', 'SC4182EC-Hypnogram.npy', 'SC4192EV-Hypnogram.npy']
# can use CUDA!!!
# tensor([[6.3500e+02, 3.6100e+02, 2.4000e+01, 1.0000e+00, 4.6000e+01, 0.0000e+00],
#         [3.3000e+01, 5.8600e+02, 1.1800e+02, 1.0000e+01, 1.3600e+02, 0.0000e+00],
#         [8.0000e+00, 1.7600e+02, 3.8630e+03, 1.5700e+02, 1.1500e+02, 0.0000e+00],
#         [0.0000e+00, 5.0000e+00, 3.5200e+02, 1.0280e+03, 1.4000e+01, 0.0000e+00],
#         [1.5000e+01, 5.2700e+02, 5.2000e+01, 1.0000e+00, 1.5420e+03, 0.0000e+00],
#         [2.0000e+00, 8.0000e+00, 3.0000e+00, 0.0000e+00, 3.0000e+00, 0.0000e+00]])
# Total data accuracy : 7654/9821 -> 77.9350%
# 91.63 35.24 87.56 85.88 83.08 nan
# 72.16 46.03 88.49 79.20 77.24 nan
# sensitivity
# tensor([0.5951, 0.6636, 0.8944, 0.7348, 0.7216, 0.0000])
# specificity
# tensor([0.9934, 0.8795, 0.9002, 0.9799, 0.9591, 1.0000])
# recall
# tensor([0.5951, 0.6636, 0.8944, 0.7348, 0.7216, 0.0000])
# precision
# tensor([0.9163, 0.3524, 0.8756, 0.8588, 0.8308,    nan])
# f1_score
# tensor([0.7216, 0.4603, 0.8849, 0.7920, 0.7724,    nan])

# %%
save_filename = './train.pth'
logging_filename = './logging.txt'
train_signal_dir = 'D:/dataset/data_2013/origin_npy/Fpz-Cz/remove_wake/each/'
test_signal_dir = 'D:/dataset/data_2013/origin_npy/Fpz-Cz/remove_wake/test/'
annotations_dir = 'D:/dataset/data_2013/origin_npy/annotations/remove_wake/'
train_model_withNoise_norm(save_filename,logging_filename,train_signal_dir, 
                           test_signal_dir,annotations_dir,
                           epochs=2000,learning_rate=0.001,step_size=100,gamma=0.5,channel=0,
                           layer_filters=[64,128,256,512],first_conv=[200,40,100],
                           optim='Adam',lf='CE',epsilon=0.8,noise_scale=1,
                           min_value=-0,max_value=0,preprocessing=True,
                           norm_methods='Standard',use_noise=True,loss_type='softmax')
# Out:
# 33941
# can use CUDA!!!
# torch.cuda.device_count() :  1
# Optimizer : Adam
# current_lr : 0.001000
# 13.775829553604126
# 7
# train dataset : 1/2000 epochs spend time : 36.2884 sec / total_loss : 1.9680 correct : 14052/33941 -> 41.4013%
# test dataset : 1/2000 epochs spend time : 0.5141 sec  / total_loss : 1.9963 correct : 4691/9821 -> 47.7650%
# best epoch : 1/2000 / val accuracy : 47.764993%
# ==============================
# current_lr : 0.001000
# 7.4334699511528015
# 7
# train dataset : 2/2000 epochs spend time : 35.0413 sec / total_loss : 1.0619 correct : 22102/33941 -> 65.1189%
# test dataset : 2/2000 epochs spend time : 0.5221 sec  / total_loss : 1.8658 correct : 5384/9821 -> 54.8213%
# best epoch : 2/2000 / val accuracy : 54.821301%
# ==============================
# current_lr : 0.001000
# 5.957632839679718
# 7
# train dataset : 3/2000 epochs spend time : 35.0753 sec / total_loss : 0.8511 correct : 25382/33941 -> 74.7827%
# test dataset : 3/2000 epochs spend time : 0.5231 sec  / total_loss : 1.4807 correct : 6040/9821 -> 61.5009%
# best epoch : 3/2000 / val accuracy : 61.500865%
# ==============================
# current_lr : 0.001000
# 5.5645835399627686
# 7
# train dataset : 4/2000 epochs spend time : 35.0296 sec / total_loss : 0.7949 correct : 25990/33941 -> 76.5741%
# test dataset : 4/2000 epochs spend time : 0.5171 sec  / total_loss : 1.4419 correct : 6349/9821 -> 64.6472%
# best epoch : 4/2000 / val accuracy : 64.647185%
# ==============================
# current_lr : 0.001000
# 5.113698720932007
# 7
# train dataset : 5/2000 epochs spend time : 34.9697 sec / total_loss : 0.7305 correct : 26802/33941 -> 78.9664%
# test dataset : 5/2000 epochs spend time : 0.5221 sec  / total_loss : 1.4166 correct : 6242/9821 -> 63.5577%
# best epoch : 4/2000 / val accuracy : 64.647185%
# ==============================
# current_lr : 0.001000
# 5.02783077955246
# 7
# train dataset : 6/2000 epochs spend time : 35.0003 sec / total_loss : 0.7183 correct : 26826/33941 -> 79.0372%
# test dataset : 6/2000 epochs spend time : 0.5201 sec  / total_loss : 1.4522 correct : 6276/9821 -> 63.9039%
# best epoch : 4/2000 / val accuracy : 64.647185%
# ==============================
# current_lr : 0.001000
# 4.934076189994812
# 7
# train dataset : 7/2000 epochs spend time : 34.9361 sec / total_loss : 0.7049 correct : 27110/33941 -> 79.8739%
# test dataset : 7/2000 epochs spend time : 0.5313 sec  / total_loss : 1.3985 correct : 6438/9821 -> 65.5534%
# best epoch : 7/2000 / val accuracy : 65.553406%
# ==============================
# current_lr : 0.001000
# 4.9295074343681335
# 7
# train dataset : 8/2000 epochs spend time : 35.0877 sec / total_loss : 0.7042 correct : 27024/33941 -> 79.6205%
# test dataset : 8/2000 epochs spend time : 0.5188 sec  / total_loss : 1.3719 correct : 6593/9821 -> 67.1317%
# best epoch : 8/2000 / val accuracy : 67.131657%
# ==============================
# current_lr : 0.001000
# 4.84050989151001
# 7
# train dataset : 9/2000 epochs spend time : 35.0236 sec / total_loss : 0.6915 correct : 27131/33941 -> 79.9358%
# test dataset : 9/2000 epochs spend time : 0.5171 sec  / total_loss : 1.5109 correct : 6571/9821 -> 66.9076%
# best epoch : 8/2000 / val accuracy : 67.131657%
# ==============================
# current_lr : 0.001000
# 4.738055408000946
# 7
# train dataset : 10/2000 epochs spend time : 34.9917 sec / total_loss : 0.6769 correct : 27348/33941 -> 80.5751%
# test dataset : 10/2000 epochs spend time : 0.5166 sec  / total_loss : 1.3944 correct : 6560/9821 -> 66.7956%
# best epoch : 8/2000 / val accuracy : 67.131657%
# ==============================
# current_lr : 0.001000
# 4.715086281299591
# 7
# train dataset : 11/2000 epochs spend time : 34.9833 sec / total_loss : 0.6736 correct : 27384/33941 -> 80.6812%
# test dataset : 11/2000 epochs spend time : 0.5161 sec  / total_loss : 1.3721 correct : 6607/9821 -> 67.2742%
# best epoch : 11/2000 / val accuracy : 67.274208%
# ==============================
# current_lr : 0.001000
# 4.716997504234314
# 7
# train dataset : 12/2000 epochs spend time : 35.0336 sec / total_loss : 0.6739 correct : 27377/33941 -> 80.6606%
# test dataset : 12/2000 epochs spend time : 0.5191 sec  / total_loss : 1.4458 correct : 6576/9821 -> 66.9586%
# best epoch : 11/2000 / val accuracy : 67.274208%
# ==============================
# current_lr : 0.001000
# 4.5663211941719055
# 7
# train dataset : 13/2000 epochs spend time : 34.9518 sec / total_loss : 0.6523 correct : 27630/33941 -> 81.4060%
# test dataset : 13/2000 epochs spend time : 0.5168 sec  / total_loss : 1.4363 correct : 6657/9821 -> 67.7833%
# best epoch : 13/2000 / val accuracy : 67.783321%
# ==============================
# current_lr : 0.001000
# 4.512737154960632
# 7
# train dataset : 14/2000 epochs spend time : 35.0022 sec / total_loss : 0.6447 correct : 27804/33941 -> 81.9186%
# test dataset : 14/2000 epochs spend time : 0.5161 sec  / total_loss : 1.3745 correct : 6743/9821 -> 68.6590%
# best epoch : 14/2000 / val accuracy : 68.658996%
# ==============================
# current_lr : 0.001000
# 4.5162288546562195
# 7
# train dataset : 15/2000 epochs spend time : 34.9511 sec / total_loss : 0.6452 correct : 27668/33941 -> 81.5179%
# test dataset : 15/2000 epochs spend time : 0.5179 sec  / total_loss : 1.4479 correct : 6742/9821 -> 68.6488%
# best epoch : 14/2000 / val accuracy : 68.658996%
# ==============================
# current_lr : 0.001000
# 4.558324456214905
# 7
# train dataset : 16/2000 epochs spend time : 34.9617 sec / total_loss : 0.6512 correct : 27659/33941 -> 81.4914%
# test dataset : 16/2000 epochs spend time : 0.5151 sec  / total_loss : 1.3875 correct : 6750/9821 -> 68.7303%
# best epoch : 16/2000 / val accuracy : 68.730272%
# ==============================
# current_lr : 0.001000
# 4.526927709579468
# 7
# train dataset : 17/2000 epochs spend time : 35.0216 sec / total_loss : 0.6467 correct : 27708/33941 -> 81.6358%
# test dataset : 17/2000 epochs spend time : 0.5161 sec  / total_loss : 1.3995 correct : 6701/9821 -> 68.2313%
# best epoch : 16/2000 / val accuracy : 68.730272%
# ==============================
# current_lr : 0.001000
# 4.53508460521698
# 7
# train dataset : 18/2000 epochs spend time : 38.9068 sec / total_loss : 0.6479 correct : 27716/33941 -> 81.6594%
# test dataset : 18/2000 epochs spend time : 0.5840 sec  / total_loss : 1.1328 correct : 6808/9821 -> 69.3208%
# best epoch : 18/2000 / val accuracy : 69.320843%
# ==============================
# current_lr : 0.001000
# 4.4796048402786255
# 7
# train dataset : 19/2000 epochs spend time : 37.6667 sec / total_loss : 0.6399 correct : 27819/33941 -> 81.9628%
# test dataset : 19/2000 epochs spend time : 0.5449 sec  / total_loss : 1.4510 correct : 6588/9821 -> 67.0807%
# best epoch : 18/2000 / val accuracy : 69.320843%
# ==============================
# current_lr : 0.001000
# 4.507055103778839
# 7
# train dataset : 20/2000 epochs spend time : 37.2819 sec / total_loss : 0.6439 correct : 27668/33941 -> 81.5179%
# test dataset : 20/2000 epochs spend time : 0.5443 sec  / total_loss : 1.2826 correct : 6823/9821 -> 69.4736%
# best epoch : 20/2000 / val accuracy : 69.473577%
# ==============================
# current_lr : 0.001000
# 4.413876235485077
# 7
# train dataset : 21/2000 epochs spend time : 36.8800 sec / total_loss : 0.6306 correct : 27888/33941 -> 82.1661%
# test dataset : 21/2000 epochs spend time : 0.5343 sec  / total_loss : 1.3981 correct : 6701/9821 -> 68.2313%
# best epoch : 20/2000 / val accuracy : 69.473577%
# ==============================
# current_lr : 0.001000
# 4.55385023355484
# 7
# train dataset : 22/2000 epochs spend time : 36.6361 sec / total_loss : 0.6506 correct : 27611/33941 -> 81.3500%
# test dataset : 22/2000 epochs spend time : 0.5573 sec  / total_loss : 1.3604 correct : 6767/9821 -> 68.9034%
# best epoch : 20/2000 / val accuracy : 69.473577%
# ==============================
# current_lr : 0.001000
# 4.4159398674964905
# 7
# train dataset : 23/2000 epochs spend time : 36.8626 sec / total_loss : 0.6308 correct : 27848/33941 -> 82.0483%
# test dataset : 23/2000 epochs spend time : 0.5201 sec  / total_loss : 1.2581 correct : 6800/9821 -> 69.2394%
# best epoch : 20/2000 / val accuracy : 69.473577%
# ==============================
# current_lr : 0.001000
# 4.278265118598938
# 7
# train dataset : 24/2000 epochs spend time : 38.3908 sec / total_loss : 0.6112 correct : 28144/33941 -> 82.9204%
# test dataset : 24/2000 epochs spend time : 0.5537 sec  / total_loss : 1.3067 correct : 6790/9821 -> 69.1376%
# best epoch : 20/2000 / val accuracy : 69.473577%
# ==============================
# current_lr : 0.001000
# 4.3197014927864075
# 7
# train dataset : 25/2000 epochs spend time : 38.7799 sec / total_loss : 0.6171 correct : 28031/33941 -> 82.5874%
# test dataset : 25/2000 epochs spend time : 0.5477 sec  / total_loss : 1.1065 correct : 6833/9821 -> 69.5754%
# best epoch : 25/2000 / val accuracy : 69.575400%
# ==============================
# current_lr : 0.001000
# 4.312192678451538
# 7
# train dataset : 26/2000 epochs spend time : 37.9626 sec / total_loss : 0.6160 correct : 28068/33941 -> 82.6964%
# test dataset : 26/2000 epochs spend time : 0.5311 sec  / total_loss : 1.1358 correct : 6788/9821 -> 69.1172%
# best epoch : 25/2000 / val accuracy : 69.575400%
# ==============================
# current_lr : 0.001000
# 4.277885258197784
# 7
# train dataset : 27/2000 epochs spend time : 36.8100 sec / total_loss : 0.6111 correct : 28110/33941 -> 82.8202%
# test dataset : 27/2000 epochs spend time : 0.5171 sec  / total_loss : 1.2495 correct : 6833/9821 -> 69.5754%
# best epoch : 25/2000 / val accuracy : 69.575400%
# ==============================
# current_lr : 0.001000
# 4.220045626163483
# 7
# train dataset : 28/2000 epochs spend time : 37.2813 sec / total_loss : 0.6029 correct : 28227/33941 -> 83.1649%
# test dataset : 28/2000 epochs spend time : 0.5227 sec  / total_loss : 1.2761 correct : 6822/9821 -> 69.4634%
# best epoch : 25/2000 / val accuracy : 69.575400%
# ==============================
# current_lr : 0.001000
# 4.234243452548981
# 7
# train dataset : 29/2000 epochs spend time : 36.3970 sec / total_loss : 0.6049 correct : 28202/33941 -> 83.0912%
# test dataset : 29/2000 epochs spend time : 0.5377 sec  / total_loss : 1.1016 correct : 6874/9821 -> 69.9929%
# best epoch : 29/2000 / val accuracy : 69.992872%
# ==============================
# current_lr : 0.001000
# 4.28606915473938
# 7
# train dataset : 30/2000 epochs spend time : 35.6444 sec / total_loss : 0.6123 correct : 28085/33941 -> 82.7465%
# test dataset : 30/2000 epochs spend time : 0.5218 sec  / total_loss : 1.0398 correct : 6863/9821 -> 69.8809%
# best epoch : 29/2000 / val accuracy : 69.992872%
# ==============================
# current_lr : 0.001000
# 4.142565011978149
# 7
# train dataset : 31/2000 epochs spend time : 39.5685 sec / total_loss : 0.5918 correct : 28345/33941 -> 83.5126%
# test dataset : 31/2000 epochs spend time : 0.5594 sec  / total_loss : 1.0187 correct : 6882/9821 -> 70.0743%
# best epoch : 31/2000 / val accuracy : 70.074331%
# ==============================
# current_lr : 0.001000
# 4.164855659008026
# 7
# train dataset : 32/2000 epochs spend time : 41.8379 sec / total_loss : 0.5950 correct : 28320/33941 -> 83.4389%
# test dataset : 32/2000 epochs spend time : 0.5760 sec  / total_loss : 1.3027 correct : 6852/9821 -> 69.7689%
# best epoch : 31/2000 / val accuracy : 70.074331%
# ==============================
# current_lr : 0.001000
# 4.130418598651886
# 7
# train dataset : 33/2000 epochs spend time : 41.9113 sec / total_loss : 0.5901 correct : 28387/33941 -> 83.6363%
# test dataset : 33/2000 epochs spend time : 0.5757 sec  / total_loss : 1.1589 correct : 6909/9821 -> 70.3493%
# best epoch : 33/2000 / val accuracy : 70.349252%
# ==============================
# current_lr : 0.001000
# 4.265265583992004
# 7
# train dataset : 34/2000 epochs spend time : 42.1275 sec / total_loss : 0.6093 correct : 28292/33941 -> 83.3564%
# test dataset : 34/2000 epochs spend time : 0.5549 sec  / total_loss : 1.0427 correct : 6835/9821 -> 69.5958%
# best epoch : 33/2000 / val accuracy : 70.349252%
# ==============================
# current_lr : 0.001000
# 4

# best epoch : 41/2000 / val accuracy : 71.123104%
# ==============================
# current_lr : 0.000500
# 3.5349591076374054
# 7
# train dataset : 58/2000 epochs spend time : 58.1581 sec / total_loss : 0.5050 correct : 29476/33941 -> 86.8448%
# test dataset : 58/2000 epochs spend time : 0.6394 sec  / total_loss : 1.0172 correct : 6937/9821 -> 70.6344%
# best epoch : 41/2000 / val accuracy : 71.123104%
# ==============================
# current_lr : 0.000500
# 3.506791204214096
# 7
# train dataset : 59/2000 epochs spend time : 57.9828 sec / total_loss : 0.5010 correct : 29499/33941 -> 86.9126%
# test dataset : 59/2000 epochs spend time : 0.6375 sec  / total_loss : 1.0122 correct : 7006/9821 -> 71.3369%
# best epoch : 59/2000 / val accuracy : 71.336931%
# ==============================
# current_lr : 0.000500
# 3.480506181716919
# 7
# train dataset : 60/2000 epochs spend time : 60.0367 sec / total_loss : 0.4972 correct : 29538/33941 -> 87.0275%
# test dataset : 60/2000 epochs spend time : 0.6568 sec  / total_loss : 1.0690 correct : 6920/9821 -> 70.4613%
# best epoch : 59/2000 / val accuracy : 71.336931%
# ==============================
# current_lr : 0.000500
# 3.49187895655632
# 7
# train dataset : 61/2000 epochs spend time : 58.5181 sec / total_loss : 0.4988 correct : 29585/33941 -> 87.1660%
# test dataset : 61/2000 epochs spend time : 0.6340 sec  / total_loss : 1.0834 correct : 6952/9821 -> 70.7871%
# best epoch : 59/2000 / val accuracy : 71.336931%
# ==============================
# current_lr : 0.000500
# 3.4770026206970215
# 7
# train dataset : 62/2000 epochs spend time : 58.8701 sec / total_loss : 0.4967 correct : 29581/33941 -> 87.1542%
# test dataset : 62/2000 epochs spend time : 0.6391 sec  / total_loss : 1.1261 correct : 6849/9821 -> 69.7383%
# best epoch : 59/2000 / val accuracy : 71.336931%
# ==============================
# current_lr : 0.000500
# 3.417686402797699
# 7
# train dataset : 63/2000 epochs spend time : 58.2763 sec / total_loss : 0.4882 correct : 29755/33941 -> 87.6668%
# test dataset : 63/2000 epochs spend time : 0.6548 sec  / total_loss : 1.0817 correct : 6886/9821 -> 70.1151%
# best epoch : 59/2000 / val accuracy : 71.336931%
# ==============================
# current_lr : 0.000500
# 3.4317650496959686
# 7
# train dataset : 64/2000 epochs spend time : 59.0910 sec / total_loss : 0.4903 correct : 29692/33941 -> 87.4812%
# test dataset : 64/2000 epochs spend time : 0.6518 sec  / total_loss : 1.0538 correct : 6943/9821 -> 70.6954%
# best epoch : 59/2000 / val accuracy : 71.336931%
# ==============================
# current_lr : 0.000250
# 3.3454722464084625
# 7
# train dataset : 65/2000 epochs spend time : 58.4124 sec / total_loss : 0.4779 correct : 29842/33941 -> 87.9232%
# test dataset : 65/2000 epochs spend time : 0.6189 sec  / total_loss : 1.0316 correct : 6966/9821 -> 70.9296%
# best epoch : 59/2000 / val accuracy : 71.336931%
# ==============================
# current_lr : 0.000250
# 3.3528073728084564
# 7
# train dataset : 66/2000 epochs spend time : 59.7432 sec / total_loss : 0.4790 correct : 29813/33941 -> 87.8377%
# test dataset : 66/2000 epochs spend time : 0.6413 sec  / total_loss : 1.0877 correct : 6956/9821 -> 70.8278%
# best epoch : 59/2000 / val accuracy : 71.336931%
# ==============================
# current_lr : 0.000250
# 3.3378873765468597
# 7
# train dataset : 67/2000 epochs spend time : 58.8304 sec / total_loss : 0.4768 correct : 29820/33941 -> 87.8583%
# test dataset : 67/2000 epochs spend time : 0.6599 sec  / total_loss : 1.0556 correct : 6953/9821 -> 70.7973%
# best epoch : 59/2000 / val accuracy : 71.336931%
# ==============================
# current_lr : 0.000250
# 3.3479461669921875
# 7
# train dataset : 68/2000 epochs spend time : 58.5125 sec / total_loss : 0.4783 correct : 29783/33941 -> 87.7493%
# test dataset : 68/2000 epochs spend time : 0.6573 sec  / total_loss : 1.0748 correct : 6891/9821 -> 70.1660%
# best epoch : 59/2000 / val accuracy : 71.336931%
# ==============================
# current_lr : 0.000250
# 3
# train dataset : 128/2000 epochs spend time : 36.1909 sec / total_loss : 0.4354 correct : 30397/33941 -> 89.5584%
# test dataset : 128/2000 epochs spend time : 0.4974 sec  / total_loss : 1.0848 correct : 6963/9821 -> 70.8991%
# Early Stopping
# best epoch : 97/2000 / accuracy : 71.683128%
# ==============================

# %% [markdown]
# #### Noise 있는 상태로 학습

# %%
def check_ResNet_custom_Confusion(test_signals_dir,annotations_dir,load_filename,save_path):
    n_categories = 6
    columns_format = ['Wake','N1','N2','N3','REM','None']

    dataset = search_npy_list(test_signals_dir)
    print(dataset)


    model = DeepSleepNet_Classification()

    cuda = torch.cuda.is_available()

    if cuda:
        print('can use CUDA!!!')
        model = model.cuda()

    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")


    test_total_loss = 0.0
    test_total_count = 0
    test_total_data = 0

    model.load_state_dict(torch.load(load_filename))

    confusion = torch.zeros(n_categories, n_categories)

    # 평가 모델 사용
    model.eval()
    for file_name in dataset:
        # get_signal_each_onechannel()
        batch_signal, batch_label = get_dataset_one_channel_norm_withoutCut(test_signal_dir,annotations_dir,file_name,
                                                                         use_noise=False,epsilon=0,noise_scale=0,
                                                                         preprocessing=True,norm_methods='Standard')
        #print(batch_signal.shape)
        batch_label_cpu = batch_label
        batch_label = torch.from_numpy(batch_label).long().to(device)
        batch_signal = signals_expand_torch_one_channel(batch_signal)
        
        with torch.no_grad():
            for index,batch_signal_each in enumerate(batch_signal):
                pred = model(batch_signal_each.reshape(1,1,-1))

                # acc
                _, predict = torch.max(pred, 1)
                check_count = (predict == batch_label[index]).sum().item()
                batch_label_one = batch_label[index].cpu().numpy()
                predict = predict.cpu().numpy()
                
                
                confusion[batch_label[index]][predict] += 1

                test_total_count += check_count
                test_total_data += len(pred)
    print(confusion)
    confusion_percent = torch.zeros(n_categories, n_categories)
    confusion_percent_recall = torch.zeros(n_categories, n_categories)
    sensitivity = torch.zeros(n_categories)
    specificity = torch.zeros(n_categories)
    recall = torch.zeros(n_categories)
    precision = torch.zeros(n_categories)
    f1_score = torch.zeros(n_categories)

    tp_fp = confusion.sum(dim=0)
    tp_fn = confusion.sum(dim=1)
    tn_fp = torch.zeros(n_categories)
    for i in range(6):
        for z in range(6):
            if z != i:
                tn_fp[i] += tp_fn[z]
    for index in range(n_categories):
        confusion_percent[index] = confusion[index] / tp_fp.float()
        confusion_percent_recall[index] = confusion[index] / tp_fn.float()
        tn = confusion.sum() - confusion.sum(dim=0)[index] - confusion.sum(dim=1)[index] + confusion[index][index]
        sensitivity[index] = confusion[index][index] / float(tp_fn[index])
        specificity[index] = tn / float(tn_fp[index])
        precision[index] = confusion[index][index] / float(tp_fp[index])

        recall[index] = sensitivity[index]

    f1_score = 2 * (precision * recall) / (precision + recall)
    test_total_loss /= len(dataset)
    test_accuracy = test_total_count / test_total_data * 100
    print('Total data accuracy : %d/%d -> %.4f%%' % (test_total_count, test_total_data, test_accuracy))
    stdout = ''
    for i in range(6):
        stdout += '%.2f '%(confusion_percent[i][i]*100)
    stdout += '\n'
    sys.stdout.write(stdout)
    confusion_percent_f1 = 2 * (confusion_percent * confusion_percent_recall) / (
                confusion_percent + confusion_percent_recall)
    stdout = ''
    for i in range(6):
        stdout += '%.2f '%(confusion_percent_f1[i][i]*100)
    stdout += '\n'
    sys.stdout.write(stdout)

    label = ['Wake', 'N1', 'N2', 'N3', 'REM']
    # Plot confusion matrix
    plt.imshow(confusion_percent, interpolation='none', cmap='GnBu')
    for (i, j), z in np.ndenumerate(confusion_percent):
        # print(i, j, z)
        plt.text(j, i, '%.2f%%' % (z * 100), ha='center', va='center', color='Red', fontSize=11, fontweight='bold')
    plt.title('confusion_matrix_precision')
    plt.xticks(np.arange(0, 6), label)
    plt.yticks(np.arange(0, 6), label)
    plt.xlabel("pred label")
    plt.ylabel("truth label")
    plt.savefig(save_path+'confusion_matrix_%d.png')
    plt.show()

    plt.imshow(confusion_percent_f1, interpolation='none', cmap='GnBu')
    for (i, j), z in np.ndenumerate(confusion_percent_f1):
        # print(i, j, z)
        plt.text(j, i, '%.2f%%' % (z * 100), ha='center', va='center', color='Red', fontSize=11, fontweight='bold')
    plt.title('confusion_matrix_F1 score')
    plt.xticks(np.arange(0, 6), label)
    plt.yticks(np.arange(0, 6), label)
    plt.xlabel("pred label")
    plt.ylabel("truth label")
    plt.savefig(save_path+'confusion_matrix_f1score_%d.png')
    plt.show()

    print('sensitivity')
    print(sensitivity)
    print('specificity')
    print(specificity)
    print('recall')
    print(recall)
    print('precision')
    print(precision)
    print('f1_score')
    print(f1_score)

def make_result_channel_new():
    load_filename = './train.pth'
    logging_filename = './logging.txt'
    save_path = './result/'
    os.makedirs(save_path,exist_ok=True)
    test_signals_dir = 'D:/dataset/data_2013/origin_npy/Fpz-Cz/remove_wake/test/'
    annotations_dir = 'D:/dataset/data_2013/origin_npy/annotations/remove_wake/'
    check_ResNet_custom_Confusion(test_signals_dir,annotations_dir,load_filename,save_path)
make_result_channel_new()
# Out:
# ['SC4002EC-Hypnogram.npy', 'SC4022EJ-Hypnogram.npy', 'SC4031EC-Hypnogram.npy', 'SC4042EC-Hypnogram.npy', 'SC4072EH-Hypnogram.npy', 'SC4101EC-Hypnogram.npy', 'SC4141EU-Hypnogram.npy', 'SC4151EC-Hypnogram.npy', 'SC4182EC-Hypnogram.npy', 'SC4192EV-Hypnogram.npy']
# can use CUDA!!!
# tensor([[7.5900e+02, 2.3200e+02, 1.5000e+01, 0.0000e+00, 6.1000e+01, 0.0000e+00],
#         [6.1000e+01, 5.7600e+02, 1.9000e+01, 0.0000e+00, 2.2700e+02, 0.0000e+00],
#         [1.2000e+01, 2.4500e+02, 3.4540e+03, 4.2000e+01, 5.6600e+02, 0.0000e+00],
#         [1.0000e+00, 1.0000e+01, 4.7600e+02, 8.8300e+02, 2.9000e+01, 0.0000e+00],
#         [3.6000e+01, 2.2400e+02, 2.0000e+00, 0.0000e+00, 1.8750e+03, 0.0000e+00],
#         [3.0000e+00, 8.0000e+00, 3.0000e+00, 0.0000e+00, 2.0000e+00, 0.0000e+00]])
# Total data accuracy : 7547/9821 -> 76.8455%
# 87.04 44.48 87.02 95.46 67.93 nan
# 78.29 52.89 83.35 75.99 76.58 nan
# sensitivity
# tensor([0.7113, 0.6523, 0.7997, 0.6312, 0.8774, 0.0000])
# specificity
# tensor([0.9871, 0.9196, 0.9064, 0.9950, 0.8848, 1.0000])
# recall
# tensor([0.7113, 0.6523, 0.7997, 0.6312, 0.8774, 0.0000])
# precision
# tensor([0.8704, 0.4448, 0.8702, 0.9546, 0.6793,    nan])
# f1_score
# tensor([0.7829, 0.5289, 0.8335, 0.7599, 0.7658,    nan])

# %% [markdown]
# #### use Noise

# %% [markdown]
# #### 4258.  2762. 17340.  2000.  7522.    59 결과

# %%
def train_model_withNoise_norm(save_filename,logging_filename,train_signal_dir, test_signal_dir,annotations_dir
                               ,epochs=2000,learning_rate=0.001,step_size=100,gamma=0.5,channel=0,
                               layer_filters=[64,128,256,512],first_conv=[200,40,100],optim='Adam',lf='CE',
                               epsilon=0.7,noise_scale=2e-6,min_value=-1e-4,max_value=1e-4,preprocessing=True,
                               norm_methods='Standard',use_noise=True,loss_type='softmax'):
    # Adam optimizer param
    b1 = 0.5
    b2 = 0.999

    beta = 0.001

    check_file = open(logging_filename, 'w')  # logging file

    train_dataset_list = []
    
    for i in range(6):
        if i == 3:
            train_dataset_list.append(search_npy_list_withdir(train_signal_dir+'%d/'%i))
        else:
            train_dataset_list.append(search_npy_list_withdir(train_signal_dir+'%d/'%i))
    
    train_dataset_list = list(itertools.chain(*train_dataset_list))
    print(len(train_dataset_list))

    best_accuracy = 0.
    best_epoch = 0

    test_dataset_list = search_npy_list(test_signal_dir)

    train_dataset_len = len(train_dataset_list)
    test_dataset_len = len(test_dataset_list)
    test_batch_size = test_dataset_len


    model = DeepSleepNet_Classification()

    #model = resnet18_200hz(in_channel=1,layer_filters=layer_filters,first_conv=first_conv,use_batchnorm=True,num_classes=5)

    model.apply(weights_init) # weight init

    cuda = torch.cuda.is_available()

    if cuda:
        print('can use CUDA!!!')
        model = model.cuda()
    #summary(model,[1,6000])
    print('torch.cuda.device_count() : ', torch.cuda.device_count())
    if torch.cuda.device_count() > 1:
        print('Multi GPU Activation !!!')
        #model = nn.DataParallel(model)

    # loss funcition
    if lf == 'CE':
        loss_fn = nn.CrossEntropyLoss().to(device)
    elif lf == 'CEW':
        samples_per_cls = [27,15,41,5,11]
        no_of_classes = 5
        effective_num = 1.0 - np.power(beta,samples_per_cls)
        #print(effective_num)
        weights = (1.0 - beta) / np.array(effective_num)
        #print(weights)
        weights = weights / np.sum(weights) * no_of_classes
        weights = torch.tensor(weights).float()
        weights = weights.to(device)
        loss_fn = nn.CrossEntropyLoss(weight=weights).to(device)
    elif lf == 'FL':
        loss_fn = FocalLoss(gamma=2).to(device)
    elif lf == 'CBL':
        loss_fn = CB_loss(samples_per_cls=[27,15,41,5,11],no_of_classes=5,loss_type=loss_type,beta=0.9999,gamma=2.0)
    #loss_fn = FocalLoss(gamma=2).to(device)

    # optimizer ADAM (SGD의 경우에는 정상적으로 학습이 진행되지 않았음)
    if optim == 'Adam':
        print('Optimizer : Adam')
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(b1, b2))
    elif optim == 'RMS':
        print('Optimizer : RMSprop')
        optimizer = torch.optim.RMSprop(model.parameters(), lr=learning_rate)
    elif optim == 'SGD':
        print('Optimizer : SGD')
        optimizer = torch.optim.SGD(model.parameters(),lr=learning_rate,momentum=0.9)

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer=optimizer, mode='min', factor=gamma, patience=10,
                                                           min_lr=1e-6)
    #stride = 40 일 때, batch_size = 20이면 16GB정도의 메모리 사용
    batch_size = 5000
    norm_square = 2

    
    for epoch in range(epochs):
        train_dataset = suffle_dataset_list(train_dataset_list) # 매 epoch마다 train_dataset shuffle !
        count = 0  # check batch
        train_total_loss = 0.0
        train_total_count = 0
        train_total_data = 0

        val_total_loss = 0.0
        val_total_count = 0
        val_total_data = 0

        test_total_loss = 0.0
        test_total_count = 0
        test_total_data = 0

        start_time = time.time()
        model.train()
        output_str = 'current_lr : %f\n'%(optimizer.state_dict()['param_groups'][0]['lr'])
        sys.stdout.write(output_str)
        check_file.write(output_str)
        train_size = 0
        for index, file_name in enumerate(train_dataset):
            if index % batch_size == 0:
                batch_signal, batch_label = get_dataset_one_channel_norm_withoutCut_each(file_name,
                                                                         use_noise=use_noise,epsilon=epsilon,noise_scale=noise_scale,
                                                                         preprocessing=preprocessing,norm_methods=norm_methods)
            else:
                new_signal, new_label = get_dataset_one_channel_norm_withoutCut_each(file_name,
                                                                         use_noise=use_noise,epsilon=epsilon,noise_scale=noise_scale,
                                                                         preprocessing=preprocessing,norm_methods=norm_methods)

                batch_signal = torch.cat((batch_signal, new_signal),dim=1)
                batch_label = np.concatenate((batch_label, new_label))
            count += 1
            if count == batch_size or index == len(train_dataset) - 1:  # batch 학습 시작!
                batch_signal = signals_expand_torch_one_channel(batch_signal)
                #batch_signal = signals_expand_torch_one_channel(batch_signal)
                # batch_signal = torch.from_numpy(batch_signal).float().to(device)
                batch_label = torch.from_numpy(batch_label).long().to(device)
                optimizer.zero_grad()
                # print(batch_signal.shape)
                # print(batch_signal)
                pred = model(batch_signal)
                norm = 0

                for parameter in model.parameters():
                    norm += torch.norm(parameter, p=norm_square)

                loss = loss_fn(pred, batch_label) + beta * norm
                #print('loss : ',loss.item())
                # loss = loss_fn(pred, batch_label)
                # acc
                _, predict = torch.max(pred, 1)
                check_count = (predict == batch_label).sum().item()

                train_total_loss += loss.item()
                train_size +=1
                train_total_count += check_count
                train_total_data += len(batch_signal)
                loss.backward()
                optimizer.step()

                del (batch_signal)
                del (batch_label)
                del (loss)
                del (pred)
                torch.cuda.empty_cache()
                count = 0
        print(train_total_loss)
        print(train_size)
        train_total_loss /= train_size
        train_accuracy = train_total_count / int(len(train_dataset_list)) * 100

        output_str = 'train dataset : %d/%d epochs spend time : %.4f sec / total_loss : %.4f correct : %d/%d -> %.4f%%\n' \
                     % (epoch + 1, epochs, time.time() - start_time, train_total_loss,
                        train_total_count, train_total_data, train_accuracy)
        sys.stdout.write(output_str)
        check_file.write(output_str)

    

        #check test dataset
        start_time = time.time()
        for file_name in test_dataset_list:
            batch_signal, batch_label = get_dataset_one_channel_norm_withoutCut(test_signal_dir,annotations_dir,file_name,
                                                                         use_noise=False,epsilon=epsilon,noise_scale=noise_scale,
                                                                         preprocessing=preprocessing,norm_methods=norm_methods)

            batch_signal = signals_expand_torch_one_channel(batch_signal)

            batch_label = torch.from_numpy(batch_label).long().to(device)

            with torch.no_grad():
                pred = model(batch_signal)

                loss = loss_fn(pred, batch_label)

                # acc
                _, predict = torch.max(pred, 1)
                check_count = (predict == batch_label).sum().item()

                test_total_loss += loss.item()
                test_total_count += check_count
                test_total_data += len(batch_signal)

                # 사용하지 않는 변수 제거
                del (batch_signal)
                del (batch_label)
                del (loss)
                del (pred)
                torch.cuda.empty_cache()
        test_total_loss /= test_batch_size
        test_accuracy = test_total_count / test_total_data * 100



        output_str = 'test dataset : %d/%d epochs spend time : %.4f sec  / total_loss : %.4f correct : %d/%d -> %.4f%%\n' \
                     % (epoch + 1, epochs, time.time() - start_time, test_total_loss,
                        test_total_count, test_total_data, test_accuracy)
        sys.stdout.write(output_str)
        check_file.write(output_str)

        scheduler.step(float(test_total_loss))
        #scheduler.step()

        if epoch == 0:
            best_accuracy = test_accuracy
            best_epoch = epoch
            save_file = save_filename
            #save_file = save_path + 'best_SleepEEGNet_CNN_channel%d.pth'%channel
            torch.save(model.state_dict(),save_file)
            stop_count = 0
        else:
            if best_accuracy < test_accuracy:
                best_accuracy = test_accuracy
                best_epoch = epoch
                save_file = save_filename
                torch.save(model.state_dict(), save_file)
                stop_count = 0
            else:
                stop_count += 1
        if stop_count > 30:
            print('Early Stopping')
            break

        output_str = 'best epoch : %d/%d / val accuracy : %f%%\n' \
                     % (best_epoch+1, epochs, best_accuracy)
        sys.stdout.write(output_str)
        print('=' * 30)


    output_str = 'best epoch : %d/%d / accuracy : %f%%\n' \
                 % (best_epoch+1, epochs, best_accuracy)
    sys.stdout.write(output_str)
    check_file.write(output_str)
    print('=' * 30)

    check_file.close()

# %%
save_filename = './train.pth'
logging_filename = './logging.txt'
train_signal_dir = 'D:/dataset/data_2013/origin_npy/Fpz-Cz/remove_wake/each/'
test_signal_dir = 'D:/dataset/data_2013/origin_npy/Fpz-Cz/remove_wake/test/'
annotations_dir = 'D:/dataset/data_2013/origin_npy/annotations/remove_wake/'
train_model_withNoise_norm(save_filename,logging_filename,train_signal_dir, 
                           test_signal_dir,annotations_dir,
                           epochs=2000,learning_rate=0.001,step_size=100,gamma=0.5,channel=0,
                           layer_filters=[64,128,256,512],first_conv=[200,40,100],
                           optim='Adam',lf='CE',epsilon=0,noise_scale=0,
                           min_value=-0,max_value=0,preprocessing=True,
                           norm_methods='Standard',use_noise=False,loss_type='softmax')
# Out:
# 37516
# can use CUDA!!!
# torch.cuda.device_count() :  1
# Optimizer : Adam
# current_lr : 0.001000
# 16.252869129180908
# 8
# train dataset : 1/2000 epochs spend time : 34.3865 sec / total_loss : 2.0316 correct : 14456/37516 -> 38.5329%
# test dataset : 1/2000 epochs spend time : 0.5211 sec  / total_loss : 1.4639 correct : 5137/9821 -> 52.3063%
# best epoch : 1/2000 / val accuracy : 52.306282%
# ==============================
# current_lr : 0.001000
# 7.9093451499938965
# 8
# train dataset : 2/2000 epochs spend time : 33.3287 sec / total_loss : 0.9887 correct : 25415/37516 -> 67.7444%
# test dataset : 2/2000 epochs spend time : 0.5137 sec  / total_loss : 1.0997 correct : 6021/9821 -> 61.3074%
# best epoch : 2/2000 / val accuracy : 61.307403%
# ==============================
# current_lr : 0.001000
# 6.361969232559204
# 8
# train dataset : 3/2000 epochs spend time : 33.9350 sec / total_loss : 0.7952 correct : 28614/37516 -> 76.2715%
# test dataset : 3/2000 epochs spend time : 0.5537 sec  / total_loss : 0.8136 correct : 6801/9821 -> 69.2496%
# best epoch : 3/2000 / val accuracy : 69.249567%
# ==============================
# current_lr : 0.001000
# 6.327542722225189
# 8
# train dataset : 4/2000 epochs spend time : 34.6819 sec / total_loss : 0.7909 correct : 28527/37516 -> 76.0396%
# test dataset : 4/2000 epochs spend time : 0.5023 sec  / total_loss : 0.8141 correct : 6741/9821 -> 68.6386%
# best epoch : 3/2000 / val accuracy : 69.249567%
# ==============================
# current_lr : 0.001000
# 5.807366788387299
# 8
# train dataset : 5/2000 epochs spend time : 34.3250 sec / total_loss : 0.7259 correct : 29486/37516 -> 78.5958%
# test dataset : 5/2000 epochs spend time : 0.5131 sec  / total_loss : 0.7739 correct : 6923/9821 -> 70.4918%
# best epoch : 5/2000 / val accuracy : 70.491803%
# ==============================
# current_lr : 0.001000
# 5.693140268325806
# 8
# train dataset : 6/2000 epochs spend time : 35.7517 sec / total_loss : 0.7116 correct : 29709/37516 -> 79.1902%
# test dataset : 6/2000 epochs spend time : 0.5369 sec  / total_loss : 0.7984 correct : 6857/9821 -> 69.8198%
# best epoch : 5/2000 / val accuracy : 70.491803%
# ==============================
# current_lr : 0.001000
# 5.611688792705536
# 8
# train dataset : 7/2000 epochs spend time : 35.5245 sec / total_loss : 0.7015 correct : 29906/37516 -> 79.7153%
# test dataset : 7/2000 epochs spend time : 0.5310 sec  / total_loss : 0.8413 correct : 6774/9821 -> 68.9746%
# best epoch : 5/2000 / val accuracy : 70.491803%
# ==============================
# current_lr : 0.001000
# 5.500217020511627
# 8
# train dataset : 8/2000 epochs spend time : 35.3414 sec / total_loss : 0.6875 correct : 29966/37516 -> 79.8753%
# test dataset : 8/2000 epochs spend time : 0.5250 sec  / total_loss : 0.7419 correct : 7064/9821 -> 71.9275%
# best epoch : 8/2000 / val accuracy : 71.927502%
# ==============================
# current_lr : 0.001000
# 5.600735247135162
# 8
# train dataset : 9/2000 epochs spend time : 35.1755 sec / total_loss : 0.7001 correct : 29807/37516 -> 79.4514%
# test dataset : 9/2000 epochs spend time : 0.5151 sec  / total_loss : 0.7901 correct : 6959/9821 -> 70.8584%
# best epoch : 8/2000 / val accuracy : 71.927502%
# ==============================
# current_lr : 0.001000
# 5.481973469257355
# 8
# train dataset : 10/2000 epochs spend time : 36.4092 sec / total_loss : 0.6852 correct : 30034/37516 -> 80.0565%
# test dataset : 10/2000 epochs spend time : 0.5338 sec  / total_loss : 0.6969 correct : 7267/9821 -> 73.9945%
# best epoch : 10/2000 / val accuracy : 73.994502%
# ==============================
# current_lr : 0.001000
# 5.334678471088409
# 8
# train dataset : 11/2000 epochs spend time : 34.1582 sec / total_loss : 0.6668 correct : 30379/37516 -> 80.9761%
# test dataset : 11/2000 epochs spend time : 0.5368 sec  / total_loss : 0.6641 correct : 7387/9821 -> 75.2164%
# best epoch : 11/2000 / val accuracy : 75.216373%
# ==============================
# current_lr : 0.001000
# 5.337880194187164
# 8
# train dataset : 12/2000 epochs spend time : 34.5799 sec / total_loss : 0.6672 correct : 30262/37516 -> 80.6642%
# test dataset : 12/2000 epochs spend time : 0.5033 sec  / total_loss : 0.6758 correct : 7346/9821 -> 74.7989%
# best epoch : 11/2000 / val accuracy : 75.216373%
# ==============================
# current_lr : 0.001000
# 5.30424952507019
# 8
# train dataset : 13/2000 epochs spend time : 34.9311 sec / total_loss : 0.6630 correct : 30397/37516 -> 81.0241%
# test dataset : 13/2000 epochs spend time : 0.5072 sec  / total_loss : 0.6225 correct : 7571/9821 -> 77.0899%
# best epoch : 13/2000 / val accuracy : 77.089909%
# ==============================
# current_lr : 0.001000
# 5.2236610651016235
# 8
# train dataset : 14/2000 epochs spend time : 34.9558 sec / total_loss : 0.6530 correct : 30550/37516 -> 81.4319%
# test dataset : 14/2000 epochs spend time : 0.5107 sec  / total_loss : 0.7348 correct : 7208/9821 -> 73.3937%
# best epoch : 13/2000 / val accuracy : 77.089909%
# ==============================
# current_lr : 0.001000
# 5.171257793903351
# 8
# train dataset : 15/2000 epochs spend time : 34.8015 sec / total_loss : 0.6464 correct : 30570/37516 -> 81.4852%
# test dataset : 15/2000 epochs spend time : 0.5229 sec  / total_loss : 0.7410 correct : 7174/9821 -> 73.0476%
# best epoch : 13/2000 / val accuracy : 77.089909%
# ==============================
# current_lr : 0.001000
# 5.071159243583679
# 8
# train dataset : 16/2000 epochs spend time : 34.1540 sec / total_loss : 0.6339 correct : 30740/37516 -> 81.9384%
# test dataset : 16/2000 epochs spend time : 0.5225 sec  / total_loss : 0.7395 correct : 7195/9821 -> 73.2614%
# best epoch : 13/2000 / val accuracy : 77.089909%
# ==============================
# current_lr : 0.001000
# 5.175707161426544
# 8
# train dataset : 17/2000 epochs spend time : 34.5848 sec / total_loss : 0.6470 correct : 30551/37516 -> 81.4346%
# test dataset : 17/2000 epochs spend time : 0.5171 sec  / total_loss : 0.6432 correct : 7445/9821 -> 75.8069%
# best epoch : 13/2000 / val accuracy : 77.089909%
# ==============================
# current_lr : 0.001000
# 5.041519820690155
# 8
# train dataset : 18/2000 epochs spend time : 33.9684 sec / total_loss : 0.6302 correct : 30825/37516 -> 82.1649%
# test dataset : 18/2000 epochs spend time : 0.5008 sec  / total_loss : 0.6553 correct : 7436/9821 -> 75.7153%
# best epoch : 13/2000 / val accuracy : 77.089909%
# ==============================
# current_lr : 0.001000
# 5.0062578320503235
# 8
# train dataset : 19/2000 epochs spend time : 35.6159 sec / total_loss : 0.6258 correct : 30798/37516 -> 82.0930%
# test dataset : 19/2000 epochs spend time : 0.5359 sec  / total_loss : 0.6521 correct : 7479/9821 -> 76.1531%
# best epoch : 13/2000 / val accuracy : 77.089909%
# ==============================
# current_lr : 0.001000
# 5.191623330116272
# 8
# train dataset : 20/2000 epochs spend time : 35.6832 sec / total_loss : 0.6490 correct : 30517/37516 -> 81.3440%
# test dataset : 20/2000 epochs spend time : 0.5141 sec  / total_loss : 0.6464 correct : 7516/9821 -> 76.5299%
# best epoch : 13/2000 / val accuracy : 77.089909%
# ==============================
# current_lr : 0.001000
# 4.9574209451675415
# 8
# train dataset : 21/2000 epochs spend time : 35.0341 sec / total_loss : 0.6197 correct : 30818/37516 -> 82.1463%
# test dataset : 21/2000 epochs spend time : 0.5216 sec  / total_loss : 0.6437 correct : 7538/9821 -> 76.7539%
# best epoch : 13/2000 / val accuracy : 77.089909%
# ==============================
# current_lr : 0.001000
# 4.9580758810043335
# 8
# train dataset : 22/2000 epochs spend time : 34.9026 sec / total_loss : 0.6198 correct : 30902/37516 -> 82.3702%
# test dataset : 22/2000 epochs spend time : 0.5122 sec  / total_loss : 0.6140 correct : 7593/9821 -> 77.3139%
# best epoch : 22/2000 / val accuracy : 77.313919%
# ==============================
# current_lr : 0.001000
# 4.911689639091492
# 8
# train dataset : 23/2000 epochs spend time : 34.8693 sec / total_loss : 0.6140 correct : 30908/37516 -> 82.3862%
# test dataset : 23/2000 epochs spend time : 0.5270 sec  / total_loss : 0.6301 correct : 7565/9821 -> 77.0288%
# best epoch : 22/2000 / val accuracy : 77.313919%
# ==============================
# current_lr : 0.001000
# 4.851147174835205
# 8
# train dataset : 24/2000 epochs spend time : 34.9410 sec / total_loss : 0.6064 correct : 31097/37516 -> 82.8900%
# test dataset : 24/2000 epochs spend time : 0.5141 sec  / total_loss : 0.6733 correct : 7398/9821 -> 75.3284%
# best epoch : 22/2000 / val accuracy : 77.313919%
# ==============================
# current_lr : 0.001000
# 4.852604806423187
# 8
# train dataset : 25/2000 epochs spend time : 34.9414 sec / total_loss : 0.6066 correct : 31074/37516 -> 82.8287%
# test dataset : 25/2000 epochs spend time : 0.5122 sec  / total_loss : 0.6010 correct : 7672/9821 -> 78.1183%
# best epoch : 25/2000 / val accuracy : 78.118318%
# ==============================
# current_lr : 0.001000
# 5.010347962379456
# 8
# train dataset : 26/2000 epochs spend time : 34.7941 sec / total_loss : 0.6263 correct : 30756/37516 -> 81.9810%
# test dataset : 26/2000 epochs spend time : 0.5160 sec  / total_loss : 0.6002 correct : 7685/9821 -> 78.2507%
# best epoch : 26/2000 / val accuracy : 78.250687%
# ==============================
# current_lr : 0.001000
# 4.761001884937286
# 8
# train dataset : 27/2000 epochs spend time : 34.9719 sec / total_loss : 0.5951 correct : 31227/37516 -> 83.2365%
# test dataset : 27/2000 epochs spend time : 0.5280 sec  / total_loss : 0.6743 correct : 7388/9821 -> 75.2266%
# best epoch : 26/2000 / val accuracy : 78.250687%
# ==============================
# current_lr : 0.001000
# 4.769714415073395
# 8
# train dataset : 28/2000 epochs spend time : 34.9328 sec / total_loss : 0.5962 correct : 31209/37516 -> 83.1885%
# test dataset : 28/2000 epochs spend time : 0.5171 sec  / total_loss : 0.6293 correct : 7621/9821 -> 77.5990%
# best epoch : 26/2000 / val accuracy : 78.250687%
# ==============================
# current_lr : 0.001000
# 4.855736076831818
# 8
# train dataset : 29/2000 epochs spend time : 35.2258 sec / total_loss : 0.6070 correct : 31149/37516 -> 83.0286%
# test dataset : 29/2000 epochs spend time : 0.5714 sec  / total_loss : 0.7598 correct : 7273/9821 -> 74.0556%
# best epoch : 26/2000 / val accuracy : 78.250687%
# ==============================
# current_lr : 0.001000
# 4.810856282711029
# 8
# train dataset : 30/2000 epochs spend time : 34.3520 sec / total_loss : 0.6014 correct : 31161/37516 -> 83.0606%
# test dataset : 30/2000 epochs spend time : 0.5146 sec  / total_loss : 0.7210 correct : 7232/9821 -> 73.6381%
# best epoch : 26/2000 / val accuracy : 78.250687%
# ==============================
# current_lr : 0.001000
# 4.842197239398956
# 8
# train dataset : 31/2000 epochs spend time : 34.1687 sec / total_loss : 0.6053 correct : 31023/37516 -> 82.6927%
# test dataset : 31/2000 epochs spend time : 0.5231 sec  / total_loss : 0.6168 correct : 7620/9821 -> 77.5888%
# best epoch : 26/2000 / val accuracy : 78.250687%
# ==============================
# current_lr : 0.001000
# 4.633548676967621
# 8
# train dataset : 32/2000 epochs spend time : 34.1591 sec / total_loss : 0.5792 correct : 31432/37516 -> 83.7829%
# test dataset : 32/2000 epochs spend time : 0.4983 sec  / total_loss : 0.6181 correct : 7592/9821 -> 77.3037%
# best epoch : 26/2000 / val accuracy : 78.250687%
# ==============================
# current_lr : 0.001000
# 4.712021112442017
# 8
# train dataset : 33/2000 epochs spend time : 34.2607 sec / total_loss : 0.5890 correct : 31349/37516 -> 83.5617%
# test dataset : 33/2000 epochs spend time : 0.5191 sec  / total_loss : 0.5916 correct : 7706/9821 -> 78.4645%
# best epoch : 33/2000 / val accuracy : 78.464515%
# ==============================
# current_lr : 0.001000
# 4.748283267021179
# 8
# train dataset : 34/2000 epochs spend time : 33.9451 sec / total_loss : 0.5935 correct : 31209/37516 -> 83.1885%
# test dataset : 34/2000 epochs spend time : 0.5807 sec  / total_loss : 0.7224 correct : 7294/9821 -> 74.2694%
# best epoch : 33/2000 / val accuracy : 78.464515%
# ==============================
# current_lr : 0.001000
# 4.895017743110657
# 8
# train dataset : 35/2000 epochs spend time : 35.2366 sec / total_loss : 0.6119 correct : 31001/37516 -> 82.6341%
# test dataset : 35/2000 epochs spend time : 0.5489 sec  / total_loss : 0.5975 correct : 7702/9821 -> 78.4238%
# best epoch : 33/2000 / val accuracy : 78.464515%
# ==============================
# current_lr : 0.001000
# 4.70728200674057
# 8
# train dataset : 36/2000 epochs spend time : 34.8153 sec / total_loss : 0.5884 correct : 31401/37516 -> 83.7003%
# test dataset : 36/2000 epochs spend time : 0.5196 sec  / total_loss : 0.7238 correct : 7284/9821 -> 74.1676%
# best epoch : 33/2000 / val accuracy : 78.464515%
# ==============================
# current_lr : 0.001000
# 4.62397038936615
# 8
# train dataset : 37/2000 epochs spend time : 35.0246 sec / total_loss : 0.5780 correct : 31468/37516 -> 83.8789%
# test dataset : 37/2000 epochs spend time : 0.5231 sec  / total_loss : 0.6049 correct : 7652/9821 -> 77.9147%
# best epoch : 33/2000 / val accuracy : 78.464515%
# ==============================
# current_lr : 0.001000
# 4.635253667831421
# 8
# train dataset : 38/2000 epochs spend time : 35.0474 sec / total_loss : 0.5794 correct : 31474/37516 -> 83.8949%
# test dataset : 38/2000 epochs spend time : 0.5168 sec  / total_loss : 0.6396 correct : 7567/9821 -> 77.0492%
# best epoch : 33/2000 / val accuracy : 78.464515%
# ==============================
# current_lr : 0.001000
# 4.67961061000824
# 8
# train dataset : 39/2000 epochs spend time : 34.8764 sec / total_loss : 0.5850 correct : 31429/37516 -> 83.7749%
# test dataset : 39/2000 epochs spend time : 0.5206 sec  / total_loss : 0.6989 correct : 7367/9821 -> 75.0127%
# best epoch : 33/2000 / val accuracy : 78.464515%
# ==============================
# current_lr : 0.001000
# 4.7305068373680115
# 8
# train dataset : 40/2000 epochs spend time : 35.5274 sec / total_loss : 0.5913 correct : 31224/37516 -> 83.2285%
# test dataset : 40/2000 epochs spend time : 0.5332 sec  / total_loss : 0.6391 correct : 7558/9821 -> 76.9575%
# best epoch : 33/2000 / val accuracy : 78.464515%
# ==============================
# current_lr : 0.001000
# 4.571415901184082
# 8
# train dataset : 41/2000 epochs spend time : 35.6749 sec / total_loss : 0.5714 correct : 31557/37516 -> 84.1161%
# test dataset : 41/2000 epochs spend time : 0.5149 sec  / total_loss : 0.7132 correct : 7348/9821 -> 74.8193%
# best epoch : 33/2000 / val accuracy : 78.464515%
# ==============================
# current_lr : 0.001000
# 4.6328622698783875
# 8
# train dataset : 42/2000 epochs spend time : 34.9348 sec / total_loss : 0.5791 correct : 31445/37516 -> 83.8176%
# test dataset : 42/2000 epochs spend time : 0.5191 sec  / total_loss : 0.6058 correct : 7671/9821 -> 78.1081%
# best epoch : 33/2000 / val accuracy : 78.464515%
# ==============================
# current_lr : 0.001000
# 4.53529679775238
# 8
# train dataset : 43/2000 epochs spend time : 34.4064 sec / total_loss : 0.5669 correct : 31514/37516 -> 84.0015%
# test dataset : 43/2000 epochs spend time : 0.5237 sec  / total_loss : 0.6044 correct : 7731/9821 -> 78.7191%
# best epoch : 43/2000 / val accuracy : 78.719071%
# ==============================
# current_lr : 0.001000
# 4.529378294944763
# 8
# train dataset : 44/2000 epochs spend time : 34.7530 sec / total_loss : 0.5662 correct : 31631/37516 -> 84.3134%
# test dataset : 44/2000 epochs spend time : 0.5498 sec  / total_loss : 0.6405 correct : 7554/9821 -> 76.9168%
# best epoch : 43/2000 / val accuracy : 78.719071%
# ==============================
# current_lr : 0.000500
# 4.376763761043549
# 8
# train dataset : 45/2000 epochs spend time : 34.5154 sec / total_loss : 0.5471 correct : 31814/37516 -> 84.8012%
# test dataset : 45/2000 epochs spend time : 0.5230 sec  / total_loss : 0.5991 correct : 7704/9821 -> 78.4442%
# best epoch : 43/2000 / val accuracy : 78.719071%
# ==============================
# current_lr : 0.000500
# 4.25201940536499
# 8
# train dataset : 46/2000 epochs spend time : 34.1146 sec / total_loss : 0.5315 correct : 32179/37516 -> 85.7741%
# test dataset : 46/2000 epochs spend time : 0.5565 sec  / total_loss : 0.6153 correct : 7668/9821 -> 78.0776%
# best epoch : 43/2000 / val accuracy : 78.719071%
# ==============================
# current_lr : 0.000500
# 4.242071688175201
# 8
# train dataset : 47/2000 epochs spend time : 36.0212 sec / total_loss : 0.5303 correct : 32157/37516 -> 85.7154%
# test dataset : 47/2000 epochs spend time : 0.5514 sec  / total_loss : 0.6388 correct : 7543/9821 -> 76.8048%
# best epoch : 43/2000 / val accuracy : 78.719071%
# ==============================
# current_lr : 0.000500
# 4.226185858249664
# 8
# train dataset : 48/2000 epochs spend time : 35.5627 sec / total_loss : 0.5283 correct : 32209/37516 -> 85.8540%
# test dataset : 48/2000 epochs spend time : 0.5231 sec  / total_loss : 0.5948 correct : 7697/9821 -> 78.3729%
# best epoch : 43/2000 / val accuracy : 78.719071%
# ==============================
# current_lr : 0.000500
# 4.171134531497955
# 8
# train dataset : 49/2000 epochs spend time : 35.3809 sec / total_loss : 0.5214 correct : 32317/37516 -> 86.1419%
# test dataset : 49/2000 epochs spend time : 0.5205 sec  / total_loss : 0.6428 correct : 7579/9821 -> 77.1714%
# best epoch : 43/2000 / val accuracy : 78.719071%
# ==============================
# current_lr : 0.000500
# 4.179974615573883
# 8
# train dataset : 50/2000 epochs spend time : 34.6713 sec / total_loss : 0.5225 correct : 32210/37516 -> 85.8567%
# test dataset : 50/2000 epochs spend time : 0.5171 sec  / total_loss : 0.6073 correct : 7696/9821 -> 78.3627%
# best epoch : 43/2000 / val accuracy : 78.719071%
# ==============================
# current_lr : 0.000500
# 4.196825921535492
# 8
# train dataset : 51/2000 epochs spend time : 35.1735 sec / total_loss : 0.5246 correct : 32225/37516 -> 85.8967%
# test dataset : 51/2000 epochs spend time : 0.5152 sec  / total_loss : 0.5949 correct : 7690/9821 -> 78.3016%
# best epoch : 43/2000 / val accuracy : 78.719071%
# ==============================
# current_lr : 0.000500
# 4.122900307178497
# 8
# train dataset : 52/2000 epochs spend time : 34.4603 sec / total_loss : 0.5154 correct : 32309/37516 -> 86.1206%
# test dataset : 52/2000 epochs spend time : 0.5235 sec  / total_loss : 0.5972 correct : 7708/9821 -> 78.4849%
# best epoch : 43/2000 / val accuracy : 78.719071%
# ==============================
# current_lr : 0.000500
# 4.147328674793243
# 8
# train dataset : 53/2000 epochs spend time : 34.1396 sec / total_loss : 0.5184 correct : 32398/37516 -> 86.3578%
# test dataset : 53/2000 epochs spend time : 0.5329 sec  / total_loss : 0.6342 correct : 7550/9821 -> 76.8761%
# best epoch : 43/2000 / val accuracy : 78.719071%
# ==============================
# current_lr : 0.000500
# 4.15388685464859
# 8
# train dataset : 54/2000 epochs spend time : 34.1427 sec / total_loss : 0.5192 correct : 32337/37516 -> 86.1952%
# test dataset : 54/2000 epochs spend time : 0.5112 sec  / total_loss : 0.5748 correct : 7747/9821 -> 78.8820%
# best epoch : 54/2000 / val accuracy : 78.881988%
# ==============================
# current_lr : 0.000500
# 4.056869149208069
# 8
# train dataset : 55/2000 epochs spend time : 34.1379 sec / total_loss : 0.5071 correct : 32472/37516 -> 86.5551%
# test dataset : 55/2000 epochs spend time : 0.5176 sec  / total_loss : 0.6292 correct : 7627/9821 -> 77.6601%
# best epoch : 54/2000 / val accuracy : 78.881988%
# ==============================
# current_lr : 0.000500
# 4.133888900279999
# 8
# train dataset : 56/2000 epochs spend time : 35.8908 sec / total_loss : 0.5167 correct : 32327/37516 -> 86.1686%
# test dataset : 56/2000 epochs spend time : 0.5435 sec  / total_loss : 0.6131 correct : 7639/9821 -> 77.7823%
# best epoch : 54/2000 / val accuracy : 78.881988%
# ==============================
# current_lr : 0.000500
# 4.113132476806641
# 8
# train dataset : 57/2000 epochs spend time : 34.9434 sec / total_loss : 0.5141 correct : 32399/37516 -> 86.3605%
# test dataset : 57/2000 epochs spend time : 0.5349 sec  / total_loss : 0.6141 correct : 7607/9821 -> 77.4565%
# best epoch : 54/2000 / val accuracy : 78.881988%
# ==============================
# current_lr : 0.000500
# 4.068451881408691
# 8
# train dataset : 58/2000 epochs spend time : 34.1453 sec / total_loss : 0.5086 correct : 32366/37516 -> 86.2725%
# test dataset : 58/2000 epochs spend time : 0.5348 sec  / total_loss : 0.5685 correct : 7765/9821 -> 79.0653%
# best epoch : 58/2000 / val accuracy : 79.065268%
# ==============================
# current_lr : 0.000500
# 4.10112076997757
# 8
# train dataset : 59/2000 epochs spend time : 34.1720 sec / total_loss : 0.5126 correct : 32426/37516 -> 86.4325%
# test dataset : 59/2000 epochs spend time : 0.5102 sec  / total_loss : 0.6933 correct : 7472/9821 -> 76.0819%
# best epoch : 58/2000 / val accuracy : 79.065268%
# ==============================
# current_lr : 0.000500
# 4.099999308586121
# 8
# train dataset : 60/2000 epochs spend time : 34.1028 sec / total_loss : 0.5125 correct : 32387/37516 -> 86.3285%
# test dataset : 60/2000 epochs spend time : 0.5151 sec  / total_loss : 0.6238 correct : 7628/9821 -> 77.6703%
# best epoch : 58/2000 / val accuracy : 79.065268%
# ==============================
# current_lr : 0.000500
# 4.048702120780945
# 8
# train dataset : 61/2000 epochs spend time : 34.2257 sec / total_loss : 0.5061 correct : 32471/37516 -> 86.5524%
# test dataset : 61/2000 epochs spend time : 0.5305 sec  / total_loss : 0.6322 correct : 7610/9821 -> 77.4870%
# best epoch : 58/2000 / val accuracy : 79.065268%
# ==============================
# current_lr : 0.000500
# 4.033891946077347
# 8
# train dataset : 62/2000 epochs spend time : 33.2212 sec / total_loss : 0.5042 correct : 32487/37516 -> 86.5951%
# test dataset : 62/2000 epochs spend time : 0.5052 sec  / total_loss : 0.6284 correct : 7642/9821 -> 77.8129%
# best epoch : 58/2000 / val accuracy : 79.065268%
# ==============================
# current_lr : 0.000500
# 4.013735979795456
# 8
# train dataset : 63/2000 epochs spend time : 33.1618 sec / total_loss : 0.5017 correct : 32554/37516 -> 86.7736%
# test dataset : 63/2000 epochs spend time : 0.5132 sec  / total_loss : 0.5911 correct : 7753/9821 -> 78.9431%
# best epoch : 58/2000 / val accuracy : 79.065268%
# ==============================
# current_lr : 0.000500
# 4.003808617591858
# 8
# train dataset : 64/2000 epochs spend time : 33.1528 sec / total_loss : 0.5005 correct : 32523/37516 -> 86.6910%
# test dataset : 64/2000 epochs spend time : 0.5042 sec  / total_loss : 0.6024 correct : 7664/9821 -> 78.0369%
# best epoch : 58/2000 / val accuracy : 79.065268%
# ==============================
# current_lr : 0.000500
# 3.9450620114803314
# 8
# train dataset : 65/2000 epochs spend time : 33.1826 sec / total_loss : 0.4931 correct : 32668/37516 -> 87.0775%
# test dataset : 65/2000 epochs spend time : 0.5062 sec  / total_loss : 0.6002 correct : 7702/9821 -> 78.4238%
# best epoch : 58/2000 / val accuracy : 79.065268%
# ==============================
# current_lr : 0.000500
# 3.9127754271030426
# 8
# train dataset : 66/2000 epochs spend time : 33.1845 sec / total_loss : 0.4891 correct : 32735/37516 -> 87.2561%
# test dataset : 66/2000 epochs spend time : 0.5042 sec  / total_loss : 0.6486 correct : 7568/9821 -> 77.0594%
# best epoch : 58/2000 / val accuracy : 79.065268%
# ==============================
# current_lr : 0.000500
# 3.9888398349285126
# 8
# train dataset : 67/2000 epochs spend time : 33.5006 sec / total_loss : 0.4986 correct : 32513/37516 -> 86.6644%
# test dataset : 67/2000 epochs spend time : 0.5062 sec  / total_loss : 0.5746 correct : 7781/9821 -> 79.2282%
# best epoch : 67/2000 / val accuracy : 79.228185%
# ==============================
# current_lr : 0.000500
# 3.9276054203510284
# 8
# train dataset : 68/2000 epochs spend time : 33.0914 sec / total_loss : 0.4910 correct : 32822/37516 -> 87.4880%
# test dataset : 68/2000 epochs spend time : 0.5062 sec  / total_loss : 0.6151 correct : 7629/9821 -> 77.6805%
# best epoch : 67/2000 / val accuracy : 79.228185%
# ==============================
# current_lr : 0.000500
# 3.969175934791565
# 8
# train dataset : 69/2000 epochs spend time : 38.6945 sec / total_loss : 0.4961 correct : 32604/37516 -> 86.9069%
# test dataset : 69/2000 epochs spend time : 0.5478 sec  / total_loss : 0.6868 correct : 7493/9821 -> 76.2957%
# best epoch : 67/2000 / val accuracy : 79.228185%
# ==============================
# current_lr : 0.000250
# 3.8117528557777405
# 8
# train dataset : 70/2000 epochs spend time : 36.4715 sec / total_loss : 0.4765 correct : 32902/37516 -> 87.7012%
# test dataset : 70/2000 epochs spend time : 0.5706 sec  / total_loss : 0.5610 correct : 7811/9821 -> 79.5337%
# best epoch : 70/2000 / val accuracy : 79.533652%
# ==============================
# current_lr : 0.000250
# 3.778337001800537
# 8
# train dataset : 71/2000 epochs spend time : 35.7394 sec / total_loss : 0.4723 correct : 33053/37516 -> 88.1037%
# test dataset : 71/2000 epochs spend time : 0.5379 sec  / total_loss : 0.5808 correct : 7750/9821 -> 78.9125%
# best epoch : 70/2000 / val accuracy : 79.533652%
# ==============================
# current_lr : 0.000250
# 3.7501789927482605
# 8
# train dataset : 72/2000 epochs spend time : 36.3110 sec / total_loss : 0.4688 correct : 33034/37516 -> 88.0531%
# test dataset : 72/2000 epochs spend time : 0.5429 sec  / total_loss : 0.5699 correct : 7718/9821 -> 78.5867%
# best epoch : 70/2000 / val accuracy : 79.533652%
# ==============================
# current_lr : 0.000250
# 3.739384710788727
# 8
# train dataset : 73/2000 epochs spend time : 36.3437 sec / total_loss : 0.4674 correct : 33182/37516 -> 88.4476%
# test dataset : 73/2000 epochs spend time : 0.5280 sec  / total_loss : 0.5717 correct : 7768/9821 -> 79.0958%
# best epoch : 70/2000 / val accuracy : 79.533652%
# ==============================
# current_lr : 0.000250
# 3.71051424741745
# 8
# train dataset : 74/2000 epochs spend time : 36.1456 sec / total_loss : 0.4638 correct : 33132/37516 -> 88.3143%
# test dataset : 74/2000 epochs spend time : 0.5508 sec  / total_loss : 0.5472 correct : 7896/9821 -> 80.3991%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000250
# 3.7267709970474243
# 8
# train dataset : 75/2000 epochs spend time : 35.9157 sec / total_loss : 0.4658 correct : 33128/37516 -> 88.3037%
# test dataset : 75/2000 epochs spend time : 0.5369 sec  / total_loss : 0.5698 correct : 7789/9821 -> 79.3096%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000250
# 3.7070908546447754
# 8
# train dataset : 76/2000 epochs spend time : 34.9192 sec / total_loss : 0.4634 correct : 33087/37516 -> 88.1944%
# test dataset : 76/2000 epochs spend time : 0.5330 sec  / total_loss : 0.5655 correct : 7754/9821 -> 78.9533%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000250
# 3.685959219932556
# 8
# train dataset : 77/2000 epochs spend time : 36.5517 sec / total_loss : 0.4607 correct : 33204/37516 -> 88.5062%
# test dataset : 77/2000 epochs spend time : 0.5320 sec  / total_loss : 0.5742 correct : 7781/9821 -> 79.2282%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000250
# 3.6858677566051483
# 8
# train dataset : 78/2000 epochs spend time : 35.8296 sec / total_loss : 0.4607 correct : 33183/37516 -> 88.4503%
# test dataset : 78/2000 epochs spend time : 0.5389 sec  / total_loss : 0.5659 correct : 7763/9821 -> 79.0449%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000250
# 3.6706838607788086
# 8
# train dataset : 79/2000 epochs spend time : 35.5908 sec / total_loss : 0.4588 correct : 33187/37516 -> 88.4609%
# test dataset : 79/2000 epochs spend time : 0.5458 sec  / total_loss : 0.5852 correct : 7765/9821 -> 79.0653%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000250
# 3.671581506729126
# 8
# train dataset : 80/2000 epochs spend time : 35.3124 sec / total_loss : 0.4589 correct : 33137/37516 -> 88.3276%
# test dataset : 80/2000 epochs spend time : 0.5439 sec  / total_loss : 0.5802 correct : 7755/9821 -> 78.9634%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000250
# 3.6453258991241455
# 8
# train dataset : 81/2000 epochs spend time : 34.9726 sec / total_loss : 0.4557 correct : 33266/37516 -> 88.6715%
# test dataset : 81/2000 epochs spend time : 0.5349 sec  / total_loss : 0.5584 correct : 7881/9821 -> 80.2464%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000250
# 3.6180687248706818
# 8
# train dataset : 82/2000 epochs spend time : 35.3184 sec / total_loss : 0.4523 correct : 33267/37516 -> 88.6742%
# test dataset : 82/2000 epochs spend time : 0.5290 sec  / total_loss : 0.5487 correct : 7857/9821 -> 80.0020%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000250
# 3.646220773458481
# 8
# train dataset : 83/2000 epochs spend time : 35.3362 sec / total_loss : 0.4558 correct : 33176/37516 -> 88.4316%
# test dataset : 83/2000 epochs spend time : 0.5409 sec  / total_loss : 0.5631 correct : 7821/9821 -> 79.6355%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000250
# 3.6074103116989136
# 8
# train dataset : 84/2000 epochs spend time : 36.5765 sec / total_loss : 0.4509 correct : 33317/37516 -> 88.8074%
# test dataset : 84/2000 epochs spend time : 0.5409 sec  / total_loss : 0.5359 correct : 7877/9821 -> 80.2057%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000250
# 3.613766133785248
# 8
# train dataset : 85/2000 epochs spend time : 35.7354 sec / total_loss : 0.4517 correct : 33292/37516 -> 88.7408%
# test dataset : 85/2000 epochs spend time : 0.5290 sec  / total_loss : 0.5740 correct : 7800/9821 -> 79.4216%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000250
# 3.565637081861496
# 8
# train dataset : 86/2000 epochs spend time : 35.0351 sec / total_loss : 0.4457 correct : 33387/37516 -> 88.9940%
# test dataset : 86/2000 epochs spend time : 0.5449 sec  / total_loss : 0.5747 correct : 7801/9821 -> 79.4318%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000250
# 3.5515510737895966
# 8
# train dataset : 87/2000 epochs spend time : 34.9459 sec / total_loss : 0.4439 correct : 33389/37516 -> 88.9994%
# test dataset : 87/2000 epochs spend time : 0.5300 sec  / total_loss : 0.5968 correct : 7721/9821 -> 78.6172%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000250
# 3.569735437631607
# 8
# train dataset : 88/2000 epochs spend time : 34.9102 sec / total_loss : 0.4462 correct : 33376/37516 -> 88.9647%
# test dataset : 88/2000 epochs spend time : 0.5280 sec  / total_loss : 0.5825 correct : 7757/9821 -> 78.9838%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000250
# 3.530065506696701
# 8
# train dataset : 89/2000 epochs spend time : 35.4353 sec / total_loss : 0.4413 correct : 33406/37516 -> 89.0447%
# test dataset : 89/2000 epochs spend time : 0.5290 sec  / total_loss : 0.5725 correct : 7793/9821 -> 79.3504%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000250
# 3.538915127515793
# 8
# train dataset : 90/2000 epochs spend time : 35.0301 sec / total_loss : 0.4424 correct : 33468/37516 -> 89.2099%
# test dataset : 90/2000 epochs spend time : 0.5340 sec  / total_loss : 0.5525 correct : 7868/9821 -> 80.1140%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000250
# 3.515742987394333
# 8
# train dataset : 91/2000 epochs spend time : 34.7101 sec / total_loss : 0.4395 correct : 33554/37516 -> 89.4392%
# test dataset : 91/2000 epochs spend time : 0.5330 sec  / total_loss : 0.5897 correct : 7773/9821 -> 79.1467%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000250
# 3.535673648118973
# 8
# train dataset : 92/2000 epochs spend time : 34.4427 sec / total_loss : 0.4420 correct : 33422/37516 -> 89.0873%
# test dataset : 92/2000 epochs spend time : 0.5062 sec  / total_loss : 0.6220 correct : 7647/9821 -> 77.8638%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000250
# 3.4800609946250916
# 8
# train dataset : 93/2000 epochs spend time : 34.0276 sec / total_loss : 0.4350 correct : 33562/37516 -> 89.4605%
# test dataset : 93/2000 epochs spend time : 0.5122 sec  / total_loss : 0.5950 correct : 7739/9821 -> 78.8005%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000250
# 3.5128996670246124
# 8
# train dataset : 94/2000 epochs spend time : 34.1940 sec / total_loss : 0.4391 correct : 33439/37516 -> 89.1326%
# test dataset : 94/2000 epochs spend time : 0.5141 sec  / total_loss : 0.5953 correct : 7740/9821 -> 78.8107%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000250
# 3.4924831986427307
# 8
# train dataset : 95/2000 epochs spend time : 34.3109 sec / total_loss : 0.4366 correct : 33549/37516 -> 89.4258%
# test dataset : 95/2000 epochs spend time : 0.5112 sec  / total_loss : 0.6049 correct : 7717/9821 -> 78.5765%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000125
# 3.4392042756080627
# 8
# train dataset : 96/2000 epochs spend time : 34.2287 sec / total_loss : 0.4299 correct : 33659/37516 -> 89.7191%
# test dataset : 96/2000 epochs spend time : 0.5151 sec  / total_loss : 0.5874 correct : 7785/9821 -> 79.2689%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000125
# 3.4236287474632263
# 8
# train dataset : 97/2000 epochs spend time : 34.5487 sec / total_loss : 0.4280 correct : 33627/37516 -> 89.6338%
# test dataset : 97/2000 epochs spend time : 0.5112 sec  / total_loss : 0.5823 correct : 7798/9821 -> 79.4013%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000125
# 3.410710573196411
# 8
# train dataset : 98/2000 epochs spend time : 35.2477 sec / total_loss : 0.4263 correct : 33688/37516 -> 89.7964%
# test dataset : 98/2000 epochs spend time : 0.5072 sec  / total_loss : 0.5764 correct : 7761/9821 -> 79.0245%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000125
# 3.3794360756874084
# 8
# train dataset : 99/2000 epochs spend time : 33.7126 sec / total_loss : 0.4224 correct : 33810/37516 -> 90.1215%
# test dataset : 99/2000 epochs spend time : 0.5132 sec  / total_loss : 0.5695 correct : 7826/9821 -> 79.6864%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000125
# 3.381411135196686
# 8
# train dataset : 100/2000 epochs spend time : 33.2727 sec / total_loss : 0.4227 correct : 33748/37516 -> 89.9563%
# test dataset : 100/2000 epochs spend time : 0.5042 sec  / total_loss : 0.5953 correct : 7769/9821 -> 79.1060%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000125
# 3.382190614938736
# 8
# train dataset : 101/2000 epochs spend time : 33.1697 sec / total_loss : 0.4228 correct : 33774/37516 -> 90.0256%
# test dataset : 101/2000 epochs spend time : 0.5032 sec  / total_loss : 0.5804 correct : 7772/9821 -> 79.1365%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000125
# 3.3749582171440125
# 8
# train dataset : 102/2000 epochs spend time : 33.1875 sec / total_loss : 0.4219 correct : 33675/37516 -> 89.7617%
# test dataset : 102/2000 epochs spend time : 0.5003 sec  / total_loss : 0.5670 correct : 7830/9821 -> 79.7271%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000125
# 3.357198268175125
# 8
# train dataset : 103/2000 epochs spend time : 33.1895 sec / total_loss : 0.4196 correct : 33852/37516 -> 90.2335%
# test dataset : 103/2000 epochs spend time : 0.4993 sec  / total_loss : 0.5565 correct : 7847/9821 -> 79.9002%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000125
# 3.3603957295417786
# 8
# train dataset : 104/2000 epochs spend time : 33.2133 sec / total_loss : 0.4200 correct : 33828/37516 -> 90.1695%
# test dataset : 104/2000 epochs spend time : 0.5052 sec  / total_loss : 0.5921 correct : 7752/9821 -> 78.9329%
# best epoch : 74/2000 / val accuracy : 80.399145%
# ==============================
# current_lr : 0.000125
# 3.3319388926029205
# 8
# train dataset : 105/2000 epochs spend time : 33.3252 sec / total_loss : 0.4165 correct : 33816/37516 -> 90.1375%
# test dataset : 105/2000 epochs spend time : 0.5003 sec  / total_loss : 0.5697 correct : 7800/9821 -> 79.4216%
# Early Stopping
# best epoch : 74/2000 / accuracy : 80.399145%
# ==============================

# %%
def check_ResNet_custom_Confusion(test_signals_dir,annotations_dir,load_filename,save_path):
    n_categories = 6
    columns_format = ['Wake','N1','N2','N3','REM','None']

    dataset = search_npy_list(test_signals_dir)
    print(dataset)


    model = DeepSleepNet_Classification()

    cuda = torch.cuda.is_available()

    if cuda:
        print('can use CUDA!!!')
        model = model.cuda()

    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")


    test_total_loss = 0.0
    test_total_count = 0
    test_total_data = 0

    model.load_state_dict(torch.load(load_filename))

    confusion = torch.zeros(n_categories, n_categories)

    # 평가 모델 사용
    model.eval()
    for file_name in dataset:
        # get_signal_each_onechannel()
        batch_signal, batch_label = get_dataset_one_channel_norm_withoutCut(test_signal_dir,annotations_dir,file_name,
                                                                         use_noise=False,epsilon=0,noise_scale=0,
                                                                         preprocessing=True,norm_methods='Standard')
        #print(batch_signal.shape)
        batch_label_cpu = batch_label
        batch_label = torch.from_numpy(batch_label).long().to(device)
        batch_signal = signals_expand_torch_one_channel(batch_signal)
        
        with torch.no_grad():
            for index,batch_signal_each in enumerate(batch_signal):
                pred = model(batch_signal_each.reshape(1,1,-1))

                # acc
                _, predict = torch.max(pred, 1)
                check_count = (predict == batch_label[index]).sum().item()
                batch_label_one = batch_label[index].cpu().numpy()
                predict = predict.cpu().numpy()
                
                
                confusion[batch_label[index]][predict] += 1

                test_total_count += check_count
                test_total_data += len(pred)
    print(confusion)
    confusion_percent = torch.zeros(n_categories, n_categories)
    confusion_percent_recall = torch.zeros(n_categories, n_categories)
    sensitivity = torch.zeros(n_categories)
    specificity = torch.zeros(n_categories)
    recall = torch.zeros(n_categories)
    precision = torch.zeros(n_categories)
    f1_score = torch.zeros(n_categories)

    tp_fp = confusion.sum(dim=0)
    tp_fn = confusion.sum(dim=1)
    tn_fp = torch.zeros(n_categories)
    for i in range(6):
        for z in range(6):
            if z != i:
                tn_fp[i] += tp_fn[z]
    for index in range(n_categories):
        confusion_percent[index] = confusion[index] / tp_fp.float()
        confusion_percent_recall[index] = confusion[index] / tp_fn.float()
        tn = confusion.sum() - confusion.sum(dim=0)[index] - confusion.sum(dim=1)[index] + confusion[index][index]
        sensitivity[index] = confusion[index][index] / float(tp_fn[index])
        specificity[index] = tn / float(tn_fp[index])
        precision[index] = confusion[index][index] / float(tp_fp[index])

        recall[index] = sensitivity[index]

    f1_score = 2 * (precision * recall) / (precision + recall)
    test_total_loss /= len(dataset)
    test_accuracy = test_total_count / test_total_data * 100
    print('Total data accuracy : %d/%d -> %.4f%%' % (test_total_count, test_total_data, test_accuracy))
    stdout = ''
    for i in range(6):
        stdout += '%.2f '%(confusion_percent[i][i]*100)
    stdout += '\n'
    sys.stdout.write(stdout)
    confusion_percent_f1 = 2 * (confusion_percent * confusion_percent_recall) / (
                confusion_percent + confusion_percent_recall)
    stdout = ''
    for i in range(6):
        stdout += '%.2f '%(confusion_percent_f1[i][i]*100)
    stdout += '\n'
    sys.stdout.write(stdout)

    label = ['Wake', 'N1', 'N2', 'N3', 'REM']
    # Plot confusion matrix
    plt.imshow(confusion_percent, interpolation='none', cmap='GnBu')
    for (i, j), z in np.ndenumerate(confusion_percent):
        # print(i, j, z)
        plt.text(j, i, '%.2f%%' % (z * 100), ha='center', va='center', color='Red', fontSize=11, fontweight='bold')
    plt.title('confusion_matrix_precision')
    plt.xticks(np.arange(0, 6), label)
    plt.yticks(np.arange(0, 6), label)
    plt.xlabel("pred label")
    plt.ylabel("truth label")
    plt.savefig(save_path+'confusion_matrix_%d.png')
    plt.show()

    plt.imshow(confusion_percent_f1, interpolation='none', cmap='GnBu')
    for (i, j), z in np.ndenumerate(confusion_percent_f1):
        # print(i, j, z)
        plt.text(j, i, '%.2f%%' % (z * 100), ha='center', va='center', color='Red', fontSize=11, fontweight='bold')
    plt.title('confusion_matrix_F1 score')
    plt.xticks(np.arange(0, 6), label)
    plt.yticks(np.arange(0, 6), label)
    plt.xlabel("pred label")
    plt.ylabel("truth label")
    plt.savefig(save_path+'confusion_matrix_f1score_%d.png')
    plt.show()

    print('sensitivity')
    print(sensitivity)
    print('specificity')
    print(specificity)
    print('recall')
    print(recall)
    print('precision')
    print(precision)
    print('f1_score')
    print(f1_score)

def make_result_channel_new():
    load_filename = './train.pth'
    logging_filename = './logging.txt'
    save_path = './result/'
    os.makedirs(save_path,exist_ok=True)
    test_signals_dir = 'D:/dataset/data_2013/origin_npy/Fpz-Cz/remove_wake/test/'
    annotations_dir = 'D:/dataset/data_2013/origin_npy/annotations/remove_wake/'
    check_ResNet_custom_Confusion(test_signals_dir,annotations_dir,load_filename,save_path)
make_result_channel_new()
# Out:
# ['SC4002EC-Hypnogram.npy', 'SC4022EJ-Hypnogram.npy', 'SC4031EC-Hypnogram.npy', 'SC4042EC-Hypnogram.npy', 'SC4072EH-Hypnogram.npy', 'SC4101EC-Hypnogram.npy', 'SC4141EU-Hypnogram.npy', 'SC4151EC-Hypnogram.npy', 'SC4182EC-Hypnogram.npy', 'SC4192EV-Hypnogram.npy']
# can use CUDA!!!
# tensor([[7.0100e+02, 2.8300e+02, 1.2000e+01, 0.0000e+00, 7.1000e+01, 0.0000e+00],
#         [1.6000e+01, 6.4800e+02, 2.1000e+01, 2.0000e+00, 1.9600e+02, 0.0000e+00],
#         [3.0000e+00, 2.6800e+02, 3.4200e+03, 2.2200e+02, 4.0600e+02, 0.0000e+00],
#         [0.0000e+00, 2.0000e+00, 6.6000e+01, 1.3200e+03, 1.1000e+01, 0.0000e+00],
#         [4.0000e+00, 2.8300e+02, 3.0000e+00, 0.0000e+00, 1.8470e+03, 0.0000e+00],
#         [3.0000e+00, 9.0000e+00, 2.0000e+00, 0.0000e+00, 2.0000e+00, 0.0000e+00]])
# Total data accuracy : 7936/9821 -> 80.8064%
# 96.42 43.40 97.05 85.49 72.92 nan
# 78.15 54.55 87.21 89.70 79.10 nan
# sensitivity
# tensor([0.6570, 0.7339, 0.7918, 0.9435, 0.8643, 0.0000])
# specificity
# tensor([0.9970, 0.9055, 0.9811, 0.9734, 0.9107, 1.0000])
# recall
# tensor([0.6570, 0.7339, 0.7918, 0.9435, 0.8643, 0.0000])
# precision
# tensor([0.9642, 0.4340, 0.9705, 0.8549, 0.7292,    nan])
# f1_score
# tensor([0.7815, 0.5455, 0.8721, 0.8970, 0.7910,    nan])

# %% [markdown]
# #### [ 4258.  2762. 17340.  5575.  7522.    59.]
